# %% [markdown]
# <a href="https://colab.research.google.com/github/Tstrebe2/predicting-text-difficulty/blob/dave-updates/code/dave-text-cleaning-pipeline-test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# !{sys.executable} -m pip install pyspark==3.1.2 -q
# !{sys.executable} -m pip install spark-nlp==4.2.0 -q
# !{sys.executable} -m pip install -U spacy==3.4.1 -q

# !{sys.executable} -m spacy download en_core_web_lg -q
# Out:
#      |████████████████████████████████| 212.4 MB 61 kB/s
#      |████████████████████████████████| 198 kB 20.0 MB/s
#   Building wheel for pyspark (setup.py) ... done
#      |████████████████████████████████| 641 kB 5.1 MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')

# !wget https://raw.githubusercontent.com/Tstrebe2/predicting-text-difficulty/main/assets/WikiLarge_Train.csv -q
# !wget https://raw.githubusercontent.com/mahavivo/vocabulary/master/lemmas/AntBNC_lemmas_ver_001.txt -q
# !wget https://raw.githubusercontent.com/Tstrebe2/predicting-text-difficulty/main/assets/dale_chall.txt -q
# !wget https://raw.githubusercontent.com/Tstrebe2/predicting-text-difficulty/main/assets/AoA_51715_words.csv -q
# !wget https://raw.githubusercontent.com/Tstrebe2/predicting-text-difficulty/main/assets/Concreteness_ratings_Brysbaert_et_al_BRM.txt -q

# %%
import pandas as pd

aoa = pd.read_csv('/content/AoA_51715_words.csv', 
                     encoding_errors='ignore', 
                     usecols=['Lemma_highest_PoS', 'AoA_Kup_lem'],
                     ).rename({'Lemma_highest_PoS':'lemma', 'AoA_Kup_lem':'aoa'}, axis=1)

aoa = aoa.groupby('lemma').first().to_dict()['aoa']

conc = (pd.read_csv('/content/Concreteness_ratings_Brysbaert_et_al_BRM.txt', 
                   sep='\t',
                   usecols=['Word', 'Bigram', 'Conc.M'])
        .rename({'Word':'word', 'Bigram':'bigram', 'Conc.M':'conc_mean'}, axis=1))

def split_word(x):
  if x['bigram'] == 0:
    word_or_phrase = x['word']
  else:
    word_or_phrase = tuple(x['word'].split(' '))

  return {'word':word_or_phrase, 'conc_mean':x['conc_mean'] }

conc = conc.apply(split_word, axis=1, result_type='expand').set_index('word').to_dict()['conc_mean']

d_chall = set(pd.read_csv('/content/dale_chall.txt', names=['word'])['word'].tolist())

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.ml import Pipeline
import pyspark.sql.functions as F
from sparknlp.base import DocumentAssembler
from sparknlp.annotator import SentenceDetector, Tokenizer, Normalizer, Lemmatizer
import sparknlp
from pyspark.sql.types import StringType, ArrayType, FloatType, StructType
import numpy as np

spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:4.2.0")\
        .getOrCreate()

df = spark.read.csv('/content/WikiLarge_Train.csv', header=True)
df.createOrReplaceTempView('wiki')

regex1, replace1 = r'-LRB-', '('
regex2, replace2 = r'-RRB-', ')'
regex3, replace3 = r"\'\' *", ''
regex4, replace4 = r", ; *", ''
regex5, replace5 = r"; , *", ''
regex6, replace6 = r", , *", ''
regex7, replace7 = r"; ; *", ''
regex8, replace8 = r"[(] [;,-]* [)] ", ''
regex9, replace9 = r"[(] +[)] *", ''
regex10, replace10 = r" km ", "kilometers"
regex11, replace11 = r"[0-9]+(km) ", "kilometers"
regex12, replace12 = r" mph "," miles per hour "
regex13, replace13 = r"° C ","degrees Celsius"
regex14, replace14 = r"° F ","degrees Farenheit"
regex15, replace15 = r"°","degrees"
regex16, replace16 = r" %"," percent"
regex17, replace17 = r" cm"," centimeters"
regex18, replace18 = r" kg "," kilograms "

iterable = ((regex1, replace1), (regex2, replace2), (regex3, replace3),
            (regex4, replace4), (regex5, replace5), (regex6, replace6),
            (regex7, replace7), (regex8, replace8), (regex9, replace9),
            (regex10,replace10), (regex11,replace11),(regex12, replace12),
            (regex13, replace13),(regex14,replace14),(regex15,replace15),
            (regex16,replace16), (regex17,replace17),(regex18,replace18))

for regex, replace in iterable:
  query = f"""
  SELECT
    regexp_replace(original_text, '{regex}', '{replace}') as original_text, 
    label 
  FROM wiki;"""
  df = spark.sql(query)
  df.createOrReplaceTempView('wiki')

query = r"SELECT * FROM wiki WHERE LENGTH(original_text) > 20;"
df = spark.sql(query)
df.createOrReplaceTempView('wiki')

documentAssembler = DocumentAssembler()\
    .setInputCol("original_text")\
    .setOutputCol("document")

tokenizer = Tokenizer() \
    .setInputCols(["document"]) \
    .setOutputCol("token")

lemmatizer = Lemmatizer() \
    .setInputCols(["token"]) \
    .setOutputCol("lemma") \
    .setDictionary("./AntBNC_lemmas_ver_001.txt", value_delimiter ="\t", key_delimiter = "->")

nlp_pipeline = Pipeline(stages=[documentAssembler,
                               tokenizer,
                               lemmatizer,
                               ])

nlp_pipeline = nlp_pipeline.fit(df)
df = nlp_pipeline.transform(df)
df.createOrReplaceTempView('wiki')
df.show(5, 0)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |original_text                                                                                                                                                                                                                                         |label|document                                                                                                                                                                                                                                                                                         |token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |lemma                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |There is manuscript evidence that Austen continued to work on these pieces as late as the period 1809 â 11 , and that her niece and nephew , Anna and James Edward Austen , made further additions as late as 1814 .                                  |1    |[{document, 0, 211, There is manuscript evidence that Austen continued to work on these pieces as late as the period 1809 â 11 , and that her niece and nephew , Anna and James Edward Austen , made further additions as late as 1814 ., {sentence -> 0}, []}]                                  |[{token, 0, 4, There, {sentence -> 0}, []}, {token, 6, 7, is, {sentence -> 0}, []}, {token, 9, 18, manuscript, {sentence -> 0}, []}, {token, 20, 27, evidence, {sentence -> 0}, []}, {token, 29, 32, that, {sentence -> 0}, []}, {token, 34, 39, Austen, {sentence -> 0}, []}, {token, 41, 49, continued, {sentence -> 0}, []}, {token, 51, 52, to, {sentence -> 0}, []}, {token, 54, 57, work, {sentence -> 0}, []}, {token, 59, 60, on, {sentence -> 0}, []}, {token, 62, 66, these, {sentence -> 0}, []}, {token, 68, 73, pieces, {sentence -> 0}, []}, {token, 75, 76, as, {sentence -> 0}, []}, {token, 78, 81, late, {sentence -> 0}, []}, {token, 83, 84, as, {sentence -> 0}, []}, {token, 86, 88, the, {sentence -> 0}, []}, {token, 90, 95, period, {sentence -> 0}, []}, {token, 97, 100, 1809, {sentence -> 0}, []}, {token, 102, 102, â, {sentence -> 0}, []}, {token, 104, 105, 11, {sentence -> 0}, []}, {token, 107, 107, ,, {sentence -> 0}, []}, {token, 109, 111, and, {sentence -> 0}, []}, {token, 113, 116, that, {sentence -> 0}, []}, {token, 118, 120, her, {sentence -> 0}, []}, {token, 122, 126, niece, {sentence -> 0}, []}, {token, 128, 130, and, {sentence -> 0}, []}, {token, 132, 137, nephew, {sentence -> 0}, []}, {token, 139, 139, ,, {sentence -> 0}, []}, {token, 141, 144, Anna, {sentence -> 0}, []}, {token, 146, 148, and, {sentence -> 0}, []}, {token, 150, 154, James, {sentence -> 0}, []}, {token, 156, 161, Edward, {sentence -> 0}, []}, {token, 163, 168, Austen, {sentence -> 0}, []}, {token, 170, 170, ,, {sentence -> 0}, []}, {token, 172, 175, made, {sentence -> 0}, []}, {token, 177, 183, further, {sentence -> 0}, []}, {token, 185, 193, additions, {sentence -> 0}, []}, {token, 195, 196, as, {sentence -> 0}, []}, {token, 198, 201, late, {sentence -> 0}, []}, {token, 203, 204, as, {sentence -> 0}, []}, {token, 206, 209, 1814, {sentence -> 0}, []}, {token, 211, 211, ., {sentence -> 0}, []}]                                                                                                                                                                                                |[{token, 0, 4, There, {sentence -> 0}, []}, {token, 6, 7, be, {sentence -> 0}, []}, {token, 9, 18, manuscript, {sentence -> 0}, []}, {token, 20, 27, evidence, {sentence -> 0}, []}, {token, 29, 32, that, {sentence -> 0}, []}, {token, 34, 39, Austen, {sentence -> 0}, []}, {token, 41, 49, continue, {sentence -> 0}, []}, {token, 51, 52, to, {sentence -> 0}, []}, {token, 54, 57, work, {sentence -> 0}, []}, {token, 59, 60, on, {sentence -> 0}, []}, {token, 62, 66, these, {sentence -> 0}, []}, {token, 68, 73, piece, {sentence -> 0}, []}, {token, 75, 76, as, {sentence -> 0}, []}, {token, 78, 81, late, {sentence -> 0}, []}, {token, 83, 84, as, {sentence -> 0}, []}, {token, 86, 88, the, {sentence -> 0}, []}, {token, 90, 95, period, {sentence -> 0}, []}, {token, 97, 100, 1809, {sentence -> 0}, []}, {token, 102, 102, â, {sentence -> 0}, []}, {token, 104, 105, 11, {sentence -> 0}, []}, {token, 107, 107, ,, {sentence -> 0}, []}, {token, 109, 111, and, {sentence -> 0}, []}, {token, 113, 116, that, {sentence -> 0}, []}, {token, 118, 120, she, {sentence -> 0}, []}, {token, 122, 126, niece, {sentence -> 0}, []}, {token, 128, 130, and, {sentence -> 0}, []}, {token, 132, 137, nephew, {sentence -> 0}, []}, {token, 139, 139, ,, {sentence -> 0}, []}, {token, 141, 144, Anna, {sentence -> 0}, []}, {token, 146, 148, and, {sentence -> 0}, []}, {token, 150, 154, James, {sen ...
# |In a remarkable comparative analysis , Mandaean scholar Säve-Söderberg demonstrated that Mani 's Psalms of Thomas were closely related to Mandaean texts .                                                                                            |1    |[{document, 0, 153, In a remarkable comparative analysis , Mandaean scholar Säve-Söderberg demonstrated that Mani 's Psalms of Thomas were closely related to Mandaean texts ., {sentence -> 0}, []}]                                                                                            |[{token, 0, 1, In, {sentence -> 0}, []}, {token, 3, 3, a, {sentence -> 0}, []}, {token, 5, 14, remarkable, {sentence -> 0}, []}, {token, 16, 26, comparative, {sentence -> 0}, []}, {token, 28, 35, analysis, {sentence -> 0}, []}, {token, 37, 37, ,, {sentence -> 0}, []}, {token, 39, 46, Mandaean, {sentence -> 0}, []}, {token, 48, 54, scholar, {sentence -> 0}, []}, {token, 56, 69, Säve-Söderberg, {sentence -> 0}, []}, {token, 71, 82, demonstrated, {sentence -> 0}, []}, {token, 84, 87, that, {sentence -> 0}, []}, {token, 89, 92, Mani, {sentence -> 0}, []}, {token, 94, 94, ', {sentence -> 0}, []}, {token, 95, 95, s, {sentence -> 0}, []}, {token, 97, 102, Psalms, {sentence -> 0}, []}, {token, 104, 105, of, {sentence -> 0}, []}, {token, 107, 112, Thomas, {sentence -> 0}, []}, {token, 114, 117, were, {sentence -> 0}, []}, {token, 119, 125, closely, {sentence -> 0}, []}, {token, 127, 133, related, {sentence -> 0}, []}, {token, 135, 136, to, {sentence -> 0}, []}, {token, 138, 145, Mandaean, {sentence -> 0}, []}, {token, 147, 151, texts, {sentence -> 0}, []}, {token, 153, 153, ., {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |[{token, 0, 1, In, {sentence -> 0}, []}, {token, 3, 3, a, {sentence -> 0}, []}, {token, 5, 14, remarkable, {sentence -> 0}, []}, {token, 16, 26, comparative, {sentence -> 0}, []}, {token, 28, 35, analysis, {sentence -> 0}, []}, {token, 37, 37, ,, {sentence -> 0}, []}, {token, 39, 46, Mandaean, {sentence -> 0}, []}, {token, 48, 54, scholar, {sentence -> 0}, []}, {token, 56, 69, Säve-Söderberg, {sentence -> 0}, []}, {token, 71, 82, demonstrate, {sentence -> 0}, []}, {token, 84, 87, that, {sentence -> 0}, []}, {token, 89, 92, Mani, {sentence -> 0}, []}, {token, 94, 94, ', {sentence -> 0}, []}, {token, 95, 95, s, {sentence -> 0}, []}, {token, 97, 102, Psalms, {sentence -> 0}, []}, {token, 104, 105, of, {sentence -> 0}, []}, {token, 107, 112, Thomas, {sentence -> 0}, []}, {token, 114, 117, be, {sentence -> 0}, []}, {token, 119, 125, closely, {sentence -> 0}, []}, {token, 127, 133, relate, {sentence -> 0}, []}, {token, 135, 136, to, {sentence -> 0}, []}, {token, 138, 145, Mandaean, {sentence -> 0}, []}, {token, 147, 151, text, {sentence -> 0}, []}, {token, 153, 153, ., {sentence -> 0}, []}]                                                                                                                                                                                                                                                                            ...
# |Before Persephone was released to Hermes , who had been sent to retrieve her , Hades tricked her into eating pomegranate seeds , ( six or three according to the telling ) which forced her to return to the underworld for a period each year .      |1    |[{document, 0, 239, Before Persephone was released to Hermes , who had been sent to retrieve her , Hades tricked her into eating pomegranate seeds , ( six or three according to the telling ) which forced her to return to the underworld for a period each year ., {sentence -> 0}, []}]      |[{token, 0, 5, Before, {sentence -> 0}, []}, {token, 7, 16, Persephone, {sentence -> 0}, []}, {token, 18, 20, was, {sentence -> 0}, []}, {token, 22, 29, released, {sentence -> 0}, []}, {token, 31, 32, to, {sentence -> 0}, []}, {token, 34, 39, Hermes, {sentence -> 0}, []}, {token, 41, 41, ,, {sentence -> 0}, []}, {token, 43, 45, who, {sentence -> 0}, []}, {token, 47, 49, had, {sentence -> 0}, []}, {token, 51, 54, been, {sentence -> 0}, []}, {token, 56, 59, sent, {sentence -> 0}, []}, {token, 61, 62, to, {sentence -> 0}, []}, {token, 64, 71, retrieve, {sentence -> 0}, []}, {token, 73, 75, her, {sentence -> 0}, []}, {token, 77, 77, ,, {sentence -> 0}, []}, {token, 79, 83, Hades, {sentence -> 0}, []}, {token, 85, 91, tricked, {sentence -> 0}, []}, {token, 93, 95, her, {sentence -> 0}, []}, {token, 97, 100, into, {sentence -> 0}, []}, {token, 102, 107, eating, {sentence -> 0}, []}, {token, 109, 119, pomegranate, {sentence -> 0}, []}, {token, 121, 125, seeds, {sentence -> 0}, []}, {token, 127, 127, ,, {sentence -> 0}, []}, {token, 129, 129, (, {sentence -> 0}, []}, {token, 131, 133, six, {sentence -> 0}, []}, {token, 135, 136, or, {sentence -> 0}, []}, {token, 138, 142, three, {sentence -> 0}, []}, {token, 144, 152, according, {sentence -> 0}, []}, {token, 154, 155, to, {sentence -> 0}, []}, {token, 157, 159, the, {sentence -> 0}, []}, {token, 161, 167, telling, {sentence -> 0}, []}, {token, 169, 169, ), {sentence -> 0}, []}, {token, 171, 175, which, {sentence -> 0}, []}, {token, 177, 182, forced, {sentence -> 0}, []}, {token, 184, 186, her, {sentence -> 0}, []}, {token, 188, 189, to, {sentence -> 0}, []}, {token, 191, 196, return, {sentence -> 0}, []}, {token, 198, 199, to, {sentence -> 0}, []}, {token, 201, 203, the, {sentence -> 0}, []}, {token, 205, 214, underworld, {sentence -> 0}, []}, {token, 216, 218, for, {sentence -> 0}, []}, {token, 220, 220, a, {sentence -> 0}, []}, {token, 222, 227, period, {sentence -> 0}, []}, {token, 229, 232, each, {sentence -> 0}, []}, {token, 234, 237, year, {sentence -> 0}, []}, {token, 239, 239, ., {sentence -> 0}, []}]|[{token, 0, 5, Before, {sentence -> 0}, []}, {token, 7, 16, Persephone, {sentence -> 0}, []}, {token, 18, 20, be, {sentence -> 0}, []}, {token, 22, 29, release, {sentence -> 0}, []}, {token, 31, 32, to, {sentence -> 0}, []}, {token, 34, 39, Hermes, {sentence -> 0}, []}, {token, 41, 41, ,, {sentence -> 0}, []}, {token, 43, 45, who, {sentence -> 0}, []}, {token, 47, 49, have, {sentence -> 0}, []}, {token, 51, 54, be, {sentence -> 0}, []}, {token, 56, 59, send, {sentence -> 0}, []}, {token, 61, 62, to, {sentence -> 0}, []}, {token, 64, 71, retrieve, {sentence -> 0}, []}, {token, 73, 75, she, {sentence -> 0}, []}, {token, 77, 77, ,, {sentence -> 0}, []}, {token, 79, 83, Hades, {sentence -> 0}, []}, {token, 85, 91, trick, {sentence -> 0}, []}, {token, 93, 95, she, {sentence -> 0}, []}, {token, 97, 100, into, {sentence -> 0}, []}, {token, 102, 107, eat, {sentence -> 0}, []}, {token, 109, 119, pomegranate, {sentence -> 0}, []}, {token, 121, 125, seed, {sentence -> 0}, []}, {token, 127, 127, ,, {sentence -> 0}, []}, {token, 129, 129, (, {sentence -> 0}, []}, {token, 131, 133, six, {sentence -> 0}, []}, {token, 135, 136, or, {sentence -> 0}, []}, {token, 138, 142, three, {sentence -> 0}, []}, {token, 144, 152, accord, {sentence -> 0}, []}, {token, 154, 155, to, {sentence -> 0}, []}, {token, 157, 159, the, {sentence -> 0}, []}, {token, 161, 167, tell, {sen ...
# |Cogeneration plants are commonly found in district heating systems of cities , hospitals , prisons , oil refineries , paper mills , wastewater treatment plants , thermal enhanced oil recovery wells and industrial plants with large heating needs .|1    |[{document, 0, 245, Cogeneration plants are commonly found in district heating systems of cities , hospitals , prisons , oil refineries , paper mills , wastewater treatment plants , thermal enhanced oil recovery wells and industrial plants with large heating needs ., {sentence -> 0}, []}]|[{token, 0, 11, Cogeneration, {sentence -> 0}, []}, {token, 13, 18, plants, {sentence -> 0}, []}, {token, 20, 22, are, {sentence -> 0}, []}, {token, 24, 31, commonly, {sentence -> 0}, []}, {token, 33, 37, found, {sentence -> 0}, []}, {token, 39, 40, in, {sentence -> 0}, []}, {token, 42, 49, district, {sentence -> 0}, []}, {token, 51, 57, heating, {sentence -> 0}, []}, {token, 59, 65, systems, {sentence -> 0}, []}, {token, 67, 68, of, {sentence -> 0}, []}, {token, 70, 75, cities, {sentence -> 0}, []}, {token, 77, 77, ,, {sentence -> 0}, []}, {token, 79, 87, hospitals, {sentence -> 0}, []}, {token, 89, 89, ,, {sentence -> 0}, []}, {token, 91, 97, prisons, {sentence -> 0}, []}, {token, 99, 99, ,, {sentence -> 0}, []}, {token, 101, 103, oil, {sentence -> 0}, []}, {token, 105, 114, refineries, {sentence -> 0}, []}, {token, 116, 116, ,, {sentence -> 0}, []}, {token, 118, 122, paper, {sentence -> 0}, []}, {token, 124, 128, mills, {sentence -> 0}, []}, {token, 130, 130, ,, {sentence -> 0}, []}, {token, 132, 141, wastewater, {sentence -> 0}, []}, {token, 143, 151, treatment, {sentence -> 0}, []}, {token, 153, 158, plants, {sentence -> 0}, []}, {token, 160, 160, ,, {sentence -> 0}, []}, {token, 162, 168, thermal, {sentence -> 0}, []}, {token, 170, 177, enhanced, {sentence -> 0}, []}, {token, 179, 181, oil, {sentence -> 0}, []}, {token, 183, 190, recovery, {sentence -> 0}, []}, {token, 192, 196, wells, {sentence -> 0}, []}, {token, 198, 200, and, {sentence -> 0}, []}, {token, 202, 211, industrial, {sentence -> 0}, []}, {token, 213, 218, plants, {sentence -> 0}, []}, {token, 220, 223, with, {sentence -> 0}, []}, {token, 225, 229, large, {sentence -> 0}, []}, {token, 231, 237, heating, {sentence -> 0}, []}, {token, 239, 243, needs, {sentence -> 0}, []}, {token, 245, 245, ., {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                  |[{token, 0, 11, Cogeneration, {sentence -> 0}, []}, {token, 13, 18, plant, {sentence -> 0}, []}, {token, 20, 22, be, {sentence -> 0}, []}, {token, 24, 31, commonly, {sentence -> 0}, []}, {token, 33, 37, find, {sentence -> 0}, []}, {token, 39, 40, in, {sentence -> 0}, []}, {token, 42, 49, district, {sentence -> 0}, []}, {token, 51, 57, heat, {sentence -> 0}, []}, {token, 59, 65, system, {sentence -> 0}, []}, {token, 67, 68, of, {sentence -> 0}, []}, {token, 70, 75, city, {sentence -> 0}, []}, {token, 77, 77, ,, {sentence -> 0}, []}, {token, 79, 87, hospital, {sentence -> 0}, []}, {token, 89, 89, ,, {sentence -> 0}, []}, {token, 91, 97, prison, {sentence -> 0}, []}, {token, 99, 99, ,, {sentence -> 0}, []}, {token, 101, 103, oil, {sentence -> 0}, []}, {token, 105, 114, refinery, {sentence -> 0}, []}, {token, 116, 116, ,, {sentence -> 0}, []}, {token, 118, 122, paper, {sentence -> 0}, []}, {token, 124, 128, mill, {sentence -> 0}, []}, {token, 130, 130, ,, {sentence -> 0}, []}, {token, 132, 141, wastewater, {sentence -> 0}, []}, {token, 143, 151, treatment, {sentence -> 0}, []}, {token, 153, 158, plant, {sentence -> 0}, []}, {token, 160, 160, ,, {sentence -> 0}, []}, {token, 162, 168, thermal, {sentence -> 0}, []}, {token, 170, 177, enhance, {sentence -> 0}, []}, {token, 179, 181, oil, {sentence -> 0}, []}, {token, 183, 190, recovery, {sentence -> 0}, ...
# |Geneva is the second-most-populous city in Switzerland ( after Zürich ) and is the most populous city of Romandie ( the French-speaking part of Switzerland ) .                                                                                       |1    |[{document, 0, 158, Geneva is the second-most-populous city in Switzerland ( after Zürich ) and is the most populous city of Romandie ( the French-speaking part of Switzerland ) ., {sentence -> 0}, []}]                                                                                       |[{token, 0, 5, Geneva, {sentence -> 0}, []}, {token, 7, 8, is, {sentence -> 0}, []}, {token, 10, 12, the, {sentence -> 0}, []}, {token, 14, 33, second-most-populous, {sentence -> 0}, []}, {token, 35, 38, city, {sentence -> 0}, []}, {token, 40, 41, in, {sentence -> 0}, []}, {token, 43, 53, Switzerland, {sentence -> 0}, []}, {token, 55, 55, (, {sentence -> 0}, []}, {token, 57, 61, after, {sentence -> 0}, []}, {token, 63, 68, Zürich, {sentence -> 0}, []}, {token, 70, 70, ), {sentence -> 0}, []}, {token, 72, 74, and, {sentence -> 0}, []}, {token, 76, 77, is, {sentence -> 0}, []}, {token, 79, 81, the, {sentence -> 0}, []}, {token, 83, 86, most, {sentence -> 0}, []}, {token, 88, 95, populous, {sentence -> 0}, []}, {token, 97, 100, city, {sentence -> 0}, []}, {token, 102, 103, of, {sentence -> 0}, []}, {token, 105, 112, Romandie, {sentence -> 0}, []}, {token, 114, 114, (, {sentence -> 0}, []}, {token, 116, 118, the, {sentence -> 0}, []}, {token, 120, 134, French-speaking, {sentence -> 0}, []}, {token, 136, 139, part, {sentence -> 0}, []}, {token, 141, 142, of, {sentence -> 0}, []}, {token, 144, 154, Switzerland, {sentence -> 0}, []}, {token, 156, 156, ), {sentence -> 0}, []}, {token, 158, 158, ., {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |[{token, 0, 5, Geneva, {sentence -> 0}, []}, {token, 7, 8, be, {sentence -> 0}, []}, {token, 10, 12, the, {sentence -> 0}, []}, {token, 14, 33, second-most-populous, {sentence -> 0}, []}, {token, 35, 38, city, {sentence -> 0}, []}, {token, 40, 41, in, {sentence -> 0}, []}, {token, 43, 53, Switzerland, {sentence -> 0}, []}, {token, 55, 55, (, {sentence -> 0}, []}, {token, 57, 61, after, {sentence -> 0}, []}, {token, 63, 68, Zürich, {sentence -> 0}, []}, {token, 70, 70, ), {sentence -> 0}, []}, {token, 72, 74, and, {sentence -> 0}, []}, {token, 76, 77, be, {sentence -> 0}, []}, {token, 79, 81, the, {sentence -> 0}, []}, {token, 83, 86, most, {sentence -> 0}, []}, {token, 88, 95, populous, {sentence -> 0}, []}, {token, 97, 100, city, {sentence -> 0}, []}, {token, 102, 103, of, {sentence -> 0}, []}, {token, 105, 112, Romandie, {sentence -> 0}, []}, {token, 114, 114, (, {sentence -> 0}, []}, {token, 116, 118, the, {sentence -> 0}, []}, {token, 120, 134, French-speaking, {sentence -> 0}, []}, {token, 136, 139, part, {sentence -> 0}, []}, {token, 141, 142, of, {sentence -> 0}, []}, {token, 144, 154, Switzerland, {sentence -> 0}, []}, {token, 156, 156, ), {sentence -> 0}, []}, {token, 158, 158, ., {sentence -> 0}, []}]                                                                                                                                           ...
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# only showing top 5 rows

# %%
def get_d_chall(x):
  num = len([w for w in x if w in d_chall])
  denom = len(x)
  return num/denom

def get_aoa(x):
  arr = [aoa[w.lower()] for w in x if w.lower() in aoa]
  if len(arr) > 0:
    return arr
  else:
    return [0.0] 

def get_conc_rating(x):
  ret_val = []

  bigrams = [(f.lower(), s.lower()) for f, s in zip(x[:-1], x[1:])]
  cont = False
  
  for bigram in bigrams:
    if cont:
      cont = False
      continue

    if bigram in conc:
      cont = True
      ret_val.append(conc[bigram])
    elif bigram[0] in conc:
      ret_val.append(conc[bigram[0]])

  return ret_val

spark.udf.register('get_d_chall', get_d_chall, FloatType())
spark.udf.register('get_aoa', get_aoa, ArrayType(FloatType()))
spark.udf.register('get_conc_rating', get_conc_rating, ArrayType(FloatType()))
spark.udf.register('get_joined_text', lambda x: ' '.join(x), StringType())
spark.udf.register('array_mean', lambda x: float(np.mean(x)), FloatType())

query = r"""
SELECT 
  original_text, 
  get_joined_text(lemma.result) as lemmatized_text, 
  get_d_chall(lemma.result) as d_chall_score,
  get_aoa(lemma.result) as aoa,
  get_conc_rating(lemma.result) as conc_rating,
  label
FROM wiki;
"""
df = spark.sql(query)
df.createOrReplaceTempView('wiki')
df.show(5, 0)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |original_text                                                                                                                                                                                                                                         |lemmatized_text                                                                                                                                                                                                                 |d_chall_score|aoa                                                                                                                                                                                                                           |conc_rating                                                                                                                                                                                                               |label|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |There is manuscript evidence that Austen continued to work on these pieces as late as the period 1809 â 11 , and that her niece and nephew , Anna and James Edward Austen , made further additions as late as 1814 .                                  |There be manuscript evidence that Austen continue to work on these piece as late as the period 1809 â 11 , and that she niece and nephew , Anna and James Edward Austen , make far addition as late as 1814 .                   |0.5          |[5.25, 5.11, 12.12, 10.58, 5.53, 7.53, 3.95, 5.86, 4.01, 6.42, 4.89, 6.1, 5.28, 6.1, 3.98, 6.78, 4.57, 5.53, 3.57, 7.0, 4.57, 6.37, 4.57, 4.68, 4.88, 5.76, 6.1, 5.28, 6.1]                                                   |[2.2, 1.85, 4.57, 3.65, 1.54, 2.36, 1.55, 3.48, 3.25, 2.03, 4.14, 1.33, 2.6, 1.33, 1.43, 3.31, 1.52, 1.54, 3.36, 4.28, 1.52, 4.48, 1.52, 2.67, 2.71, 2.89, 1.33, 2.6, 1.33]                                               |1    |
# |In a remarkable comparative analysis , Mandaean scholar Säve-Söderberg demonstrated that Mani 's Psalms of Thomas were closely related to Mandaean texts .                                                                                            |In a remarkable comparative analysis , Mandaean scholar Säve-Söderberg demonstrate that Mani ' s Psalms of Thomas be closely relate to Mandaean text .                                                                          |0.20833333   |[3.69, 2.89, 9.72, 11.94, 11.32, 10.37, 9.05, 5.53, 4.55, 5.11, 10.33, 3.95, 7.78]                                                                                                                                            |[3.0, 1.46, 1.89, 1.74, 2.56, 3.5, 2.53, 1.54, 1.67, 1.85, 2.46, 2.0, 1.55, 4.93]                                                                                                                                         |1    |
# |Before Persephone was released to Hermes , who had been sent to retrieve her , Hades tricked her into eating pomegranate seeds , ( six or three according to the telling ) which forced her to return to the underworld for a period each year .      |Before Persephone be release to Hermes , who have be send to retrieve she , Hades trick she into eat pomegranate seed , ( six or three accord to the tell ) which force she to return to the underworld for a period each year .|0.6304348    |[5.45, 5.11, 8.53, 3.95, 3.81, 3.72, 5.11, 5.68, 3.95, 7.61, 3.57, 6.05, 3.57, 6.52, 2.78, 11.17, 4.72, 5.25, 4.14, 3.69, 9.65, 3.95, 3.98, 4.26, 6.58, 6.0, 3.57, 3.95, 5.61, 3.95, 3.98, 9.45, 4.39, 2.89, 6.78, 4.95, 5.24]|[1.96, 1.85, 3.24, 1.55, 1.74, 2.18, 1.85, 2.7, 1.55, 3.32, 3.36, 3.36, 3.36, 2.3, 4.44, 4.86, 4.71, 3.43, 1.72, 3.62, 1.57, 1.55, 1.43, 2.9, 1.54, 3.0, 3.36, 1.55, 2.97, 1.55, 1.43, 2.96, 1.63, 1.46, 3.31, 2.03, 3.25]|1    |
# |Cogeneration plants are commonly found in district heating systems of cities , hospitals , prisons , oil refineries , paper mills , wastewater treatment plants , thermal enhanced oil recovery wells and industrial plants with large heating needs .|Cogeneration plant be commonly find in district heat system of city , hospital , prison , oil refinery , paper mill , wastewater treatment plant , thermal enhance oil recovery well and industrial plant with large heat need .|0.53846157   |[3.95, 5.11, 5.78, 3.69, 9.79, 5.33, 9.9, 4.55, 6.56, 5.55, 7.5, 7.33, 11.11, 4.0, 8.17, 11.53, 8.11, 3.95, 11.05, 9.95, 7.33, 8.05, 6.16, 4.57, 10.22, 3.95, 4.44, 5.74, 5.33, 3.56]                                         |[4.76, 1.85, 1.73, 2.63, 3.0, 3.29, 3.79, 2.94, 1.67, 4.79, 4.64, 4.68, 4.79, 4.86, 4.12, 2.93, 4.76, 3.21, 2.21, 4.93, 2.68, 3.33, 1.52, 3.0, 4.76, 2.0, 3.37, 3.79, 1.69]                                               |1    |
# |Geneva is the second-most-populous city in Switzerland ( after Zürich ) and is the most populous city of Romandie ( the French-speaking part of Switzerland ) .                                                                                       |Geneva be the second-most-populous city in Switzerland ( after Zürich ) and be the most populous city of Romandie ( the French-speaking part of Switzerland ) .                                                                 |0.4814815    |[5.11, 3.98, 6.56, 3.69, 6.0, 4.57, 5.11, 3.98, 12.62, 6.56, 4.55, 3.98, 5.11, 4.55]                                                                                                                                          |[1.85, 1.43, 4.79, 3.0, 2.12, 1.52, 1.85, 1.43, 2.38, 2.77, 4.79, 1.67, 1.43, 3.29, 1.67]                                                                                                                                 |1    |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 5 rows

# %%
import numpy as np

spark.udf.register('array_mean', lambda x: float(np.mean(x)), FloatType())

query = r"""
SELECT 
original_text, 
lemmatized_text,
d_chall_score,
array_mean(aoa) as aoa_mean, 
array_min(aoa) as aoa_min, 
array_max(aoa) as aoa_max, 
array_mean(conc_rating) as conc_rating_mean, 
array_min(conc_rating) as conc_rating_min, 
array_max(conc_rating) as conc_rating_max,
label
FROM wiki; 
"""
df = spark.sql(query)
df.createOrReplaceTempView('wiki')
df.show(5, 0)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+-------+-------+----------------+---------------+---------------+-----+
# |original_text                                                                                                                                                                                                                                         |lemmatized_text                                                                                                                                                                                                                 |d_chall_score|aoa_mean |aoa_min|aoa_max|conc_rating_mean|conc_rating_min|conc_rating_max|label|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+-------+-------+----------------+---------------+---------------+-----+
# |There is manuscript evidence that Austen continued to work on these pieces as late as the period 1809 â 11 , and that her niece and nephew , Anna and James Edward Austen , made further additions as late as 1814 .                                  |There be manuscript evidence that Austen continue to work on these piece as late as the period 1809 â 11 , and that she niece and nephew , Anna and James Edward Austen , make far addition as late as 1814 .                   |0.5          |5.8093104|3.57   |12.12  |2.4955173       |1.33           |4.57           |1    |
# |In a remarkable comparative analysis , Mandaean scholar Säve-Söderberg demonstrated that Mani 's Psalms of Thomas were closely related to Mandaean texts .                                                                                            |In a remarkable comparative analysis , Mandaean scholar Säve-Söderberg demonstrate that Mani ' s Psalms of Thomas be closely relate to Mandaean text .                                                                          |0.20833333   |7.4023075|2.89   |11.94  |2.3342857       |1.46           |4.93           |1    |
# |Before Persephone was released to Hermes , who had been sent to retrieve her , Hades tricked her into eating pomegranate seeds , ( six or three according to the telling ) which forced her to return to the underworld for a period each year .      |Before Persephone be release to Hermes , who have be send to retrieve she , Hades trick she into eat pomegranate seed , ( six or three accord to the tell ) which force she to return to the underworld for a period each year .|0.6304348    |5.2313514|2.78   |11.17  |2.5564864       |1.43           |4.86           |1    |
# |Cogeneration plants are commonly found in district heating systems of cities , hospitals , prisons , oil refineries , paper mills , wastewater treatment plants , thermal enhanced oil recovery wells and industrial plants with large heating needs .|Cogeneration plant be commonly find in district heat system of city , hospital , prison , oil refinery , paper mill , wastewater treatment plant , thermal enhance oil recovery well and industrial plant with large heat need .|0.53846157   |6.742    |3.56   |11.53  |3.3696551       |1.52           |4.93           |1    |
# |Geneva is the second-most-populous city in Switzerland ( after Zürich ) and is the most populous city of Romandie ( the French-speaking part of Switzerland ) .                                                                                       |Geneva be the second-most-populous city in Switzerland ( after Zürich ) and be the most populous city of Romandie ( the French-speaking part of Switzerland ) .                                                                 |0.4814815    |5.455    |3.69   |12.62  |2.3993332       |1.43           |4.79           |1    |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+-------+-------+----------------+---------------+---------------+-----+
# only showing top 5 rows

# %%
df = df.toPandas()

# %%
df.head()
# Out:
#                                        original_text  \
# 0  There is manuscript evidence that Austen conti...
# 1  In a remarkable comparative analysis , Mandaea...
# 2  Before Persephone was released to Hermes , who...
# 3  Cogeneration plants are commonly found in dist...
# 4  Geneva is the second-most-populous city in Swi...
#
#                                      lemmatized_text  d_chall_score  aoa_mean  \
# 0  There be manuscript evidence that Austen conti...       0.500000  5.809310
# 1  In a remarkable comparative analysis , Mandaea...       0.208333  7.402308
# 2  Before Persephone be release to Hermes , who h...       0.630435  5.231351
# 3  Cogeneration plant be commonly find in distric...       0.538462  6.742000
# 4  Geneva be the second-most-populous city in Swi...       0.481481  5.455000
#
#    aoa_min  aoa_max  conc_rating_mean  conc_rating_min  conc_rating_max label
# 0     3.57    12.12          2.495517             1.33             4.57     1
# 1     2.89    11.94          2.334286             1.46             4.93     1
# 2     2.78    11.17          2.556486             1.43             4.86     1
# 3     3.56    11.53          3.369655             1.52             4.93     1
# 4     3.69    12.62          2.399333             1.43             4.79     1
