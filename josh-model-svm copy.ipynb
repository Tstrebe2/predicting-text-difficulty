# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix

# %%
# parameters
sample_size = -1 # if -1, then all rows are processed

features = { # true includes in the model
    'd_chall_score': True, 
    'aoa_mean': False, 
    'aoa_min': False, 
    'aoa_max': True,
    'conc_rating_mean': False, 
    'conc_rating_min': False, 
    'conc_rating_max': True, 
    'num_lemmas': True,
    'tf-idf': False
}

# %%
train = pd.read_csv('assets/Training_set.csv', delimiter='\t')
del train['Unnamed: 0']

test = pd.read_csv('assets/Testing_set.csv', delimiter='\t')
del test['Unnamed: 0']

# embed = pd.read_csv('/content/drive/Shareddrives/Milestone 2/embeddings.csv', delimiter='\t')

# %%
included_features = [k for k,v in features.items() if v and k != 'tf-idf']
if features['tf-idf']: included_features.append('lemmatized_text')

n = len(train) if sample_size == -1 else sample_size

X_train = train[included_features].sample(n)
y_train = train.iloc[X_train.index, -1]
X_test = test[included_features]
y_test = test.iloc[:, -1]

# %%
if features['tf-idf']:
    tfidf = TfidfVectorizer(min_df=25, stop_words='english', ngram_range=(1,3))
    X_train_vec = tfidf.fit_transform(X_train['lemmatized_text'])
    X_test_vec = tfidf.transform(X_test['lemmatized_text'])

    X_train_mads = csr_matrix(X_train.iloc[:, 1:-1])
    X_test_mads = csr_matrix(X_test.iloc[:, 1:-1])

    X_train = hstack((X_train_vec, X_train_mads))
    X_test = hstack((X_test_vec, X_test_mads))

try:
    del X_train['lemmatized_text'] 
    del X_test['lemmatized_text']
except:
    pass

# %%
# pipe = Pipeline([('scale', StandardScaler(with_mean=False)), ('impute', SimpleImputer()), ('svc', SVC())])


# svc = SVC()
# svc.fit(X_train_all, y_train)
# pred = svc.predict(X_test_all)
# classification_report(y_test, pred)
# pipe.fit(X_train_vec, y_train)
# pipe.score(X_test_vec, y_test)

# %%
# imputer = SimpleImputer()
# scaler = StandardScaler()

# X_train_imputed = imputer.fit_transform(X_train)
# X_test_imputed = imputer.transform(X_test)

# X_train_scaled = scaler.fit_transform(X_train_imputed)
# X_test_scaled = scaler.fit_transform(X_test_imputed)

# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel': ['linear','poly','rbf']}

# grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)

# grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.621 total time=   2.9s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.625 total time=   3.4s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.623 total time=   3.3s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.604 total time=   3.1s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.637 total time=   3.6s
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.590 total time=   6.2s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.594 total time=   6.7s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.584 total time=   6.6s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.590 total time=   7.2s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.584 total time=   6.4s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.618 total time=   6.6s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.633 total time=   7.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.628 total time=   7.5s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.619 total time=   7.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.649 total time=   6.5s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.621 total time=   3.2s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.625 total time=   3.1s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.623 total time=   3.2s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.604 total time=   3.2s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.637 total time=   3.2s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.569 total time=   3.3s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.572 total time=   3.2s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.565 total time=   3.2s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.568 total time=   4.2s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.569 total time=   3.4s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.618 total time=   5.3s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.634 total time=   5.2s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.624 total time=   5.3s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.620 total time=   5.7s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.651 total time=   5.3s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.621 total time=   2.9s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.625 total time=   4.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.623 total time=   2.9s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.604 total time=   3.1s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.637 total time=   3.1s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.521 total time=   3.1s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.521 total time=   3.1s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.521 total time=   3.1s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.522 total time=   3.3s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.522 total time=   3.1s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.621 total time=   5.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.621 total time=   5.1s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.625 total time=   5.2s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.613 total time=   5.2s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.643 total time=   5.4s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.621 total time=   2.9s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.625 total time=   2.9s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.623 total time=   3.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.604 total time=   3.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.637 total time=   3.1s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.521 total time=   3.0s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.522 total time=   3.1s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.522 total time=   3.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.589 total time=   5.6s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.599 total time=   5.8s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.593 total time=   6.8s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.599 total time=   5.6s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.596 total time=   5.8s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.621 total time=   2.9s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.625 total time=   3.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.623 total time=   3.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.604 total time=   3.1s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.637 total time=   3.1s
# [CV 1/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.2s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.2s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 4/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.522 total time=   3.3s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.522 total time=   3.1s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.521 total time=   5.7s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.521 total time=   5.6s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.521 total time=   5.6s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.522 total time=   5.7s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.522 total time=   5.5s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.620 total time=   3.8s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.625 total time=   4.8s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.624 total time=   3.8s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.603 total time=   3.8s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.636 total time=   3.8s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.590 total time=  20.7s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.593 total time=  18.7s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.583 total time=  21.2s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0.590 total time=  21.0s
# [CV 5/5] END .........C=1, gamma=1, kernel=poly;, score=0.585 total time=  22.4s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.623 total time=   5.7s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.639 total time=   5.6s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.630 total time=   5.9s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.622 total time=   5.7s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.652 total time=   5.6s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.620 total time=   3.8s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.625 total time=   3.7s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.624 total time=   3.8s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.603 total time=   3.8s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.636 total time=   3.9s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.588 total time=   3.7s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.587 total time=   3.3s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.579 total time=   3.2s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.587 total time=   3.3s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.583 total time=   4.6s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.622 total time=   5.6s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.632 total time=   6.1s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.629 total time=   5.5s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.624 total time=   5.2s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.646 total time=   5.2s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.620 total time=   3.7s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.625 total time=   3.8s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.624 total time=   3.9s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.603 total time=   3.9s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.636 total time=   3.8s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.522 total time=   3.1s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.521 total time=   3.0s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.521 total time=   3.0s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.523 total time=   3.2s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.522 total time=   3.1s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.621 total time=   5.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.625 total time=   4.9s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.625 total time=   5.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.620 total time=   5.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.649 total time=   5.0s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.620 total time=   3.6s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.625 total time=   3.8s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.624 total time=   3.7s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.603 total time=   3.9s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.636 total time=   3.7s
# [CV 1/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.521 total time=   3.2s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 3/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 4/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.522 total time=   3.1s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.522 total time=   3.1s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.621 total time=   5.1s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.626 total time=   6.1s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.626 total time=   6.5s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.603 total time=   6.7s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.639 total time=   6.7s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.620 total time=   4.6s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.625 total time=   3.9s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.624 total time=   3.7s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.603 total time=   3.7s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.636 total time=   3.8s
# [CV 1/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.8s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.4s
# [CV 3/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 4/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.522 total time=   3.0s
# [CV 5/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.522 total time=   3.1s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.592 total time=   6.2s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.600 total time=   5.7s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.597 total time=   5.6s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.600 total time=   5.5s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.598 total time=   5.6s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.620 total time=   7.0s
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=0.624 total time=   6.4s
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.624 total time=   6.8s
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=0.604 total time=   6.6s
# [CV 5/5] END ......C=10, gamma=1, kernel=linear;, score=0.637 total time=   6.3s
# [CV 1/5] END ........C=10, gamma=1, kernel=poly;, score=0.590 total time= 2.3min
# [CV 2/5] END ........C=10, gamma=1, kernel=poly;, score=0.594 total time= 2.0min
# [CV 3/5] END ........C=10, gamma=1, kernel=poly;, score=0.583 total time= 2.2min
# [CV 4/5] END ........C=10, gamma=1, kernel=poly;, score=0.590 total time= 2.7min
# [CV 5/5] END ........C=10, gamma=1, kernel=poly;, score=0.585 total time= 2.1min
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.612 total time=   7.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.639 total time=   7.1s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.618 total time=   7.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.620 total time=   7.3s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.635 total time=   7.1s
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.620 total time=   6.9s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.624 total time=   6.4s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.624 total time=   6.7s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.604 total time=   6.6s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.637 total time=   6.3s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.589 total time=   3.7s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.594 total time=   3.9s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.582 total time=   3.9s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.589 total time=   3.9s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.585 total time=   3.8s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.623 total time=   5.8s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.639 total time=   5.8s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.627 total time=   5.7s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.620 total time=   5.7s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.650 total time=   5.8s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.620 total time=   7.1s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.624 total time=   6.6s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.624 total time=   6.9s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.604 total time=   6.6s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.637 total time=   6.2s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.536 total time=   3.1s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.536 total time=   3.2s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.533 total time=   4.0s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.534 total time=   3.0s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.534 total time=   3.1s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.621 total time=   5.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.629 total time=   5.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.625 total time=   5.1s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.617 total time=   5.2s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.652 total time=   5.3s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.620 total time=   6.9s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.624 total time=   6.5s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.624 total time=   6.9s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.604 total time=   6.5s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.637 total time=   6.2s
# [CV 1/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.521 total time=   3.0s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.522 total time=   3.1s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.522 total time=   3.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.621 total time=   5.3s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.621 total time=   7.4s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.631 total time=  15.2s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.608 total time=  13.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.640 total time=   5.4s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.620 total time=   6.9s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.624 total time=   6.5s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.624 total time=   6.8s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.604 total time=   6.6s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.637 total time=   7.0s
# [CV 1/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.3s
# [CV 2/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.1s
# [CV 3/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.2s
# [CV 4/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.522 total time=   3.1s
# [CV 5/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.522 total time=   4.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.619 total time=   5.4s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.627 total time=   5.2s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.622 total time=   5.4s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.603 total time=   5.3s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.636 total time=   5.4s
# [CV 1/5] END .....C=100, gamma=1, kernel=linear;, score=0.620 total time=  21.0s
# [CV 2/5] END .....C=100, gamma=1, kernel=linear;, score=0.625 total time=  24.0s
# [CV 3/5] END .....C=100, gamma=1, kernel=linear;, score=0.623 total time=  23.1s
# [CV 4/5] END .....C=100, gamma=1, kernel=linear;, score=0.603 total time=  20.4s
# [CV 5/5] END .....C=100, gamma=1, kernel=linear;, score=0.637 total time=  20.4s
# [CV 1/5] END .......C=100, gamma=1, kernel=poly;, score=0.590 total time=18.6min
# [CV 2/5] END .......C=100, gamma=1, kernel=poly;, score=0.594 total time=17.5min
# [CV 3/5] END .......C=100, gamma=1, kernel=poly;, score=0.584 total time=26.3min
# [CV 4/5] END .......C=100, gamma=1, kernel=poly;, score=0.589 total time=18.3min
# [CV 5/5] END .......C=100, gamma=1, kernel=poly;, score=0.586 total time=36.4min
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.600 total time=  51.4s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.629 total time=  53.3s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.606 total time=  56.1s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.608 total time=  56.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.632 total time=  50.6s
# [CV 1/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.620 total time= 1.2min
# [CV 2/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.625 total time= 1.0min
# [CV 3/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.623 total time= 1.1min
# [CV 4/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.603 total time= 1.0min
# [CV 5/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.637 total time= 1.0min
# [CV 1/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.590 total time=  20.8s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.594 total time=  20.2s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.583 total time=  20.4s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.590 total time=  19.8s
# [CV 5/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.584 total time=  20.7s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.620 total time=  28.3s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.641 total time=  28.6s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.627 total time=  28.5s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.617 total time=  28.8s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.642 total time=  26.8s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.620 total time= 1.1min
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.625 total time=  35.7s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.623 total time=  19.5s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.603 total time=  20.1s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.637 total time=  19.7s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.569 total time=   2.8s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.572 total time=   2.9s
# [CV 3/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.565 total time=   2.8s
# [CV 4/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.568 total time=   2.8s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.569 total time=   2.9s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.621 total time=   5.6s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.629 total time=   5.7s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.629 total time=   5.6s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.619 total time=   5.6s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.649 total time=   5.7s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.620 total time=  19.6s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.625 total time=  19.2s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.623 total time=  19.4s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.603 total time=  19.8s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.637 total time=  19.0s
# [CV 1/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.521 total time=   2.9s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.521 total time=   2.9s
# [CV 3/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.521 total time=   3.0s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.522 total time=   2.9s
# [CV 5/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.522 total time=   3.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.621 total time=   5.3s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.625 total time=   4.9s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.623 total time=   5.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.617 total time=   5.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.648 total time=   5.0s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.620 total time=  19.7s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.625 total time=  18.8s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.623 total time=  19.5s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.603 total time=  18.9s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.637 total time=  19.0s
# [CV 1/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.0s
# [CV 2/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.521 total time=   2.9s
# [CV 3/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.521 total time=   3.0s
# [CV 4/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.522 total time=   2.9s
# [CV 5/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.522 total time=   3.3s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.620 total time=   5.4s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.624 total time=   5.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.622 total time=   6.9s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.606 total time=   7.5s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.636 total time=   7.5s
# [CV 1/5] END ....C=1000, gamma=1, kernel=linear;, score=0.620 total time= 1.7min
# [CV 2/5] END ....C=1000, gamma=1, kernel=linear;, score=0.625 total time= 1.7min
# [CV 3/5] END ....C=1000, gamma=1, kernel=linear;, score=0.623 total time= 1.7min
# [CV 4/5] END ....C=1000, gamma=1, kernel=linear;, score=0.604 total time= 1.7min
# [CV 5/5] END ....C=1000, gamma=1, kernel=linear;, score=0.633 total time= 1.7min

# %%
# print('Best Paramters: ', grid.best_params_)
# print('Best Model: ', grid.best_estimator_)

# pred = grid.predict(X_test_scaled)
# classification_report(y_test, pred)

# %%
# import pickle

# s = pickle.dumps(pipe['svc'])
