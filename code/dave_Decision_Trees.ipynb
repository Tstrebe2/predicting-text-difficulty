# %% [markdown]
# <a href="https://colab.research.google.com/github/Tstrebe2/predicting-text-difficulty/blob/dave-updates/code/dave_Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn. metrics import precision_score, recall_score, precision_recall_curve, roc_auc_score, auc, accuracy_score,f1_score
import graphviz
from sklearn.tree import export_graphviz

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filepath='drive/Shareddrives/Milestone 2/'
train = pd.read_csv(f'{filepath}Training_set.csv', 
                      sep='\t',index_col='ix')

test = pd.read_csv(f'{filepath}Testing_set.csv', sep='\t',
                     index_col='ix')

# %%
train.head()
# Out:
#                                         original_text  \
# ix
# 0   There is manuscript evidence that Austen conti...
# 1   In a remarkable comparative analysis , Mandaea...
# 2   Before Persephone was released to Hermes , who...
# 3   Cogeneration plants are commonly found in dist...
# 4   Geneva -LRB- , ; , ; , ; ; -RRB- is the second...
#
#                                       lemmatized_text  d_chall_score  \
# ix
# 0   There be manuscript evidence that Austen conti...       8.817221
# 1   In a remarkable comparative analysis , Mandaea...      12.320171
# 2   Before Persephone be release to Hermes , who h...       6.594628
# 3   Cogeneration plant be commonly find in distric...       7.015012
# 4   Geneva - LRB - , ; , ; , ; ; - RRB - be the se...       9.847729
#
#     aoa_mean  aoa_min  aoa_max  conc_rating_mean  conc_rating_min  \
# ix
# 0   5.809310     3.57    12.12          2.495517             1.33
# 1   7.402308     2.89    11.94          2.334286             1.46
# 2   5.231351     2.78    11.17          2.556486             1.43
# 3   6.742000     3.56    11.53          3.369655             1.52
# 4   5.455000     3.69    12.62          2.399333             1.43
#
#     conc_rating_max  num_lemmas  label
# ix
# 0              4.57        39.0      1
# 1              4.93        21.0      1
# 2              4.86        42.0      1
# 3              4.93        32.0      1
# 4              4.79        28.0      1

# %%
train.label.value_counts()
# Out:
# 1    187546
# 0    187546
# Name: label, dtype: int64

# %%
metrics_df = {"model_name":[],
              "model_instance":[],
              "train_accuracy": [],
              "train_precision": [],
              "train_recall": [],
              "train_f1": [],
              "train_aucprc":[],
              "train_aucroc": [],
              "test_accuracy":[],
              "test_precision":[],
              "test_f1": [],
              "test_recall":[],
              "test_aucprc":[],
              "test_aucroc": []
              }

# %%
def compute_metrics(model,model_name,X_train_data,y_train_data, X_test_data, y_test_data):
    # extract the model's hyperparameters and make that part of the identifier for the model 

    metrics_df['model_name'].append(model_name)
    metrics_df['model_instance'].append(model)
   
    # run train data
    y_pred_train = model.predict(X_train_data)
    acc = accuracy_score(y_train_data, y_pred_train)
    recall = recall_score(y_train_data,y_pred_train)
    precision = precision_score(y_train_data, y_pred_train)
    f1 = f1_score(y_train_data,y_pred_train)
    y_proba_train = model.predict_proba(X_train_data)[:,1]
    prc,rec,thres = precision_recall_curve(y_train_data, y_proba_train)
    auc_prc = auc(rec,prc)
    roc = roc_auc_score(y_train_data, y_proba_train)
   
   
    metrics_df['train_accuracy'].append(acc)
    metrics_df['train_recall'].append(recall)
    metrics_df['train_precision'].append(precision)
    metrics_df['train_f1'].append(f1)
    metrics_df['train_aucprc'].append(auc_prc)
    metrics_df['train_aucroc'].append(roc)


    #run test data
    y_pred = model.predict(X_test_data)
    acc = accuracy_score(y_test_data, y_pred)
    recall = recall_score(y_test_data,y_pred)
    precision = precision_score(y_test_data, y_pred)
    f1 = f1_score(y_test_data,y_pred)
    y_proba = model.predict_proba(X_test_data)[:,1]
    prc,rec,thres = precision_recall_curve(y_test_data, y_proba)
    auc_prc = auc(rec,prc)
    roc = roc_auc_score(y_test_data, y_proba)

    metrics_df['test_accuracy'].append(acc)
    metrics_df['test_recall'].append(recall)
    metrics_df['test_precision'].append(precision)
    metrics_df['test_f1'].append(f1)
    metrics_df['test_aucprc'].append(auc_prc)
    metrics_df['test_aucroc'].append(roc)

# %%
# Take a simple decision_tree classifier
vec = TfidfVectorizer(stop_words='english',
                      ngram_range=(1,3))
X_train_vec = vec.fit_transform(train['lemmatized_text'])

# %%
sample_df = train.groupby('label').apply(lambda x: x.sample(20000, random_state=99))
sample_df.label.value_counts()

X_train_samp = sample_df[sample_df.columns[:-1]]
y_train_samp = sample_df.label.values
# Out:
#                                                   original_text  \
# label ix
# 0     256934  The Kofun period is a time in the history of J...
#       302533  The word '' Zanzibar '' probably derives from ...
#       336731  They left the coalition and caused its collaps...
#       336554     Qiu Chuji , Chinese Taoist -LRB- d. 1227 -RRB-
#       413164                Jumada al-awwal -LRB- Jum d I -RRB-
# ...                                                         ...
# 1     48254   Broons -LRB- , Gallo : Bron -RRB- is a commune...
#       128725  Favre started at the quarterback position for ...
#       98268   Rear Admiral Grace Murray Hopper -LRB- Decembe...
#       91683   Since then we have seen robots finally reach a...
#       77053   Spy Kids is the first film of the Spy Kids tri...
#
#                                                 lemmatized_text  \
# label ix
# 0     256934  The Kofun period be a time in the history of J...
#       302533  The word '' Zanzibar '' probably derive from t...
#       336731  They leave the coalition and cause it collapse...
#       336554  Qiu Chuji , Chinese Taoist - LRB - d . 1227 - ...
#       413164            Jumada al-awwal - LRB - Jum d I - RRB -
# ...                                                         ...
# 1     48254   Broons - LRB - , Gallo : Bron - RRB - be a com...
#       128725  Favre start at the quarterback position for th...
#       98268   Rear Admiral Grace Murray Hopper - LRB - Decem...
#       91683   Since then we have see robot finally reach a m...
#       77053   Spy Kids be the first film of the Spy Kids tri...
#
#               d_chall_score  aoa_mean  aoa_min  aoa_max  conc_rating_mean  \
# label ix
# 0     256934       5.487318  4.949286     2.89     7.33          2.294286
#       302533      10.510223  5.146875     3.56    12.00          2.250555
#       336731       7.174366  6.204000     3.98    13.94          2.625000
#       336554      16.186800  0.000000     0.00     0.00               NaN
#       413164      16.137200  0.000000     0.00     0.00               NaN
# ...                     ...       ...      ...      ...               ...
# 1     48254       11.746084  5.790000     2.89    12.05          2.743333
#       128725       8.052000  5.536154     3.69    10.72          2.407692
#       98268       13.690817  6.900000     4.57     9.70          3.210000
#       91683        5.794262  5.348148     2.89    15.07          2.556429
#       77053        7.722873  5.761818     3.86    10.70          3.168182
#
#               conc_rating_min  conc_rating_max  num_lemmas
# label ix
# 0     256934             1.43             4.82        17.0
#       302533             1.33             4.21        34.0
#       336731             1.43             3.67        12.0
#       336554              NaN              NaN         8.0
#       413164              NaN              NaN         7.0
# ...                       ...              ...         ...
# 1     48254              1.43             4.76        19.0
#       128725             1.43             4.65        35.0
#       98268              1.46             4.93        24.0
#       91683              1.33             4.93        29.0
#       77053              1.43             4.71        11.0
#
# [40000 rows x 10 columns]

# %%
pipeline = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', DecisionTreeClassifier())
                    ])

parameters = {
    'tfidf__min_df': [20],
    'tfidf__stop_words': ['english'],
    'tfidf__ngram_range': [(1, 3)],
    'clf__criterion': ['gini'],
    'clf__splitter': ['best'],
    'clf__min_samples_leaf': [2,5,10],
    'clf__max_depth': [10, 20, 25, 30, 50,75, 80, 100,200,500]
}


grid_dtc_f1 = GridSearchCV(pipeline, 
                            param_grid=parameters,
                            scoring='f1', 
                            cv=StratifiedKFold(n_splits=10),
                            return_train_score=True,
                            n_jobs=-1).fit(X_train_samp['lemmatized_text'],y_train_samp)
grid_dtc_f1.best_params_
# Out:
# {'clf__criterion': 'gini',
#  'clf__max_depth': 500,
#  'clf__min_samples_leaf': 10,
#  'clf__splitter': 'best',
#  'tfidf__min_df': 20,
#  'tfidf__ngram_range': (1, 3),
#  'tfidf__stop_words': 'english'}

# %%
res = pd.DataFrame(grid_dtc_f1.cv_results_)
res[res['rank_test_score'] <=20].T
# Out:
#                                                                             9   \
# mean_fit_time                                                         3.434753
# std_fit_time                                                          0.038575
# mean_score_time                                                        0.16247
# std_score_time                                                        0.007459
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        30
# param_clf__min_samples_leaf                                                  2
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 3...
# split0_test_score                                                     0.448993
# split1_test_score                                                     0.469136
# split2_test_score                                                     0.461439
# split3_test_score                                                      0.46829
# split4_test_score                                                     0.476008
# split5_test_score                                                     0.452004
# split6_test_score                                                     0.473139
# split7_test_score                                                     0.448743
# split8_test_score                                                     0.479046
# split9_test_score                                                     0.465147
# mean_test_score                                                       0.464194
# std_test_score                                                        0.010527
# rank_test_score                                                             20
# split0_train_score                                                    0.533158
# split1_train_score                                                    0.543458
# split2_train_score                                                    0.527753
# split3_train_score                                                    0.533521
# split4_train_score                                                    0.527797
# split5_train_score                                                    0.509485
# split6_train_score                                                    0.534283
# split7_train_score                                                    0.536431
# split8_train_score                                                    0.519881
# split9_train_score                                                    0.523721
# mean_train_score                                                      0.528949
# std_train_score                                                       0.009081
#
#                                                                             10  \
# mean_fit_time                                                         3.303141
# std_fit_time                                                          0.030202
# mean_score_time                                                       0.154506
# std_score_time                                                        0.008223
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        30
# param_clf__min_samples_leaf                                                  5
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 3...
# split0_test_score                                                     0.440667
# split1_test_score                                                     0.471692
# split2_test_score                                                     0.456883
# split3_test_score                                                     0.467416
# split4_test_score                                                     0.483238
# split5_test_score                                                     0.462157
# split6_test_score                                                      0.47116
# split7_test_score                                                     0.457932
# split8_test_score                                                     0.475267
# split9_test_score                                                     0.461742
# mean_test_score                                                       0.464815
# std_test_score                                                        0.011193
# rank_test_score                                                             19
# split0_train_score                                                    0.519908
# split1_train_score                                                    0.533699
# split2_train_score                                                    0.514854
# split3_train_score                                                    0.518982
# split4_train_score                                                    0.520295
# split5_train_score                                                     0.49862
# split6_train_score                                                    0.521143
# split7_train_score                                                    0.527644
# split8_train_score                                                    0.509373
# split9_train_score                                                    0.510685
# mean_train_score                                                       0.51752
# std_train_score                                                       0.009329
#
#                                                                             12  \
# mean_fit_time                                                          4.32898
# std_fit_time                                                          0.064077
# mean_score_time                                                       0.152787
# std_score_time                                                        0.010325
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        50
# param_clf__min_samples_leaf                                                  2
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                     0.465745
# split1_test_score                                                     0.496565
# split2_test_score                                                          0.5
# split3_test_score                                                     0.500157
# split4_test_score                                                     0.506449
# split5_test_score                                                     0.498884
# split6_test_score                                                     0.489028
# split7_test_score                                                     0.456806
# split8_test_score                                                     0.511111
# split9_test_score                                                     0.513429
# mean_test_score                                                       0.493817
# std_test_score                                                        0.017708
# rank_test_score                                                             16
# split0_train_score                                                    0.599353
# split1_train_score                                                    0.614986
# split2_train_score                                                    0.600021
# split3_train_score                                                    0.605819
# split4_train_score                                                    0.599561
# split5_train_score                                                    0.598246
# split6_train_score                                                    0.602907
# split7_train_score                                                    0.595652
# split8_train_score                                                     0.59976
# split9_train_score                                                    0.599459
# mean_train_score                                                      0.601576
# std_train_score                                                       0.005148
#
#                                                                             13  \
# mean_fit_time                                                         4.071681
# std_fit_time                                                          0.042362
# mean_score_time                                                       0.155965
# std_score_time                                                        0.008751
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        50
# param_clf__min_samples_leaf                                                  5
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                     0.455141
# split1_test_score                                                     0.489014
# split2_test_score                                                     0.488278
# split3_test_score                                                      0.48972
# split4_test_score                                                      0.51052
# split5_test_score                                                     0.512402
# split6_test_score                                                      0.50527
# split7_test_score                                                      0.45847
# split8_test_score                                                     0.509259
# split9_test_score                                                     0.498902
# mean_test_score                                                       0.491697
# std_test_score                                                         0.01947
# rank_test_score                                                             17
# split0_train_score                                                    0.574235
# split1_train_score                                                    0.589099
# split2_train_score                                                    0.579406
# split3_train_score                                                    0.584366
# split4_train_score                                                    0.583333
# split5_train_score                                                    0.580894
# split6_train_score                                                    0.583806
# split7_train_score                                                    0.572114
# split8_train_score                                                    0.579036
# split9_train_score                                                    0.581942
# mean_train_score                                                      0.580823
# std_train_score                                                       0.004711
#
#                                                                             14  \
# mean_fit_time                                                          3.84098
# std_fit_time                                                          0.039681
# mean_score_time                                                       0.155324
# std_score_time                                                        0.005734
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        50
# param_clf__min_samples_leaf                                                 10
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                     0.460784
# split1_test_score                                                     0.460768
# split2_test_score                                                     0.465192
# split3_test_score                                                     0.495889
# split4_test_score                                                     0.503561
# split5_test_score                                                     0.504265
# split6_test_score                                                     0.497465
# split7_test_score                                                     0.483981
# split8_test_score                                                     0.506384
# split9_test_score                                                     0.510025
# mean_test_score                                                       0.488832
# std_test_score                                                        0.018691
# rank_test_score                                                             18
# split0_train_score                                                    0.554927
# split1_train_score                                                    0.547851
# split2_train_score                                                    0.544634
# split3_train_score                                                    0.562125
# split4_train_score                                                    0.569204
# split5_train_score                                                    0.559887
# split6_train_score                                                    0.560288
# split7_train_score                                                    0.576841
# split8_train_score                                                    0.555883
# split9_train_score                                                    0.566951
# mean_train_score                                                      0.559859
# std_train_score                                                       0.009206
#
#                                                                             15  \
# mean_fit_time                                                         5.230428
# std_fit_time                                                          0.075325
# mean_score_time                                                       0.151023
# std_score_time                                                        0.004744
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        75
# param_clf__min_samples_leaf                                                  2
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 7...
# split0_test_score                                                     0.487606
# split1_test_score                                                     0.495005
# split2_test_score                                                     0.514044
# split3_test_score                                                     0.503947
# split4_test_score                                                     0.506776
# split5_test_score                                                     0.504702
# split6_test_score                                                     0.523478
# split7_test_score                                                     0.509145
# split8_test_score                                                     0.526062
# split9_test_score                                                     0.538114
# mean_test_score                                                       0.510888
# std_test_score                                                        0.014285
# rank_test_score                                                             14
# split0_train_score                                                     0.66879
# split1_train_score                                                     0.64842
# split2_train_score                                                    0.666529
# split3_train_score                                                    0.663327
# split4_train_score                                                    0.641319
# split5_train_score                                                    0.662462
# split6_train_score                                                    0.669724
# split7_train_score                                                    0.676956
# split8_train_score                                                    0.670393
# split9_train_score                                                    0.669584
# mean_train_score                                                       0.66375
# std_train_score                                                       0.010303
#
#                                                                             16  \
# mean_fit_time                                                         4.676066
# std_fit_time                                                          0.057763
# mean_score_time                                                       0.155737
# std_score_time                                                        0.013962
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        75
# param_clf__min_samples_leaf                                                  5
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 7...
# split0_test_score                                                     0.488299
# split1_test_score                                                     0.500956
# split2_test_score                                                      0.51218
# split3_test_score                                                     0.487106
# split4_test_score                                                     0.507817
# split5_test_score                                                     0.529376
# split6_test_score                                                     0.528936
# split7_test_score                                                     0.496489
# split8_test_score                                                     0.523981
# split9_test_score                                                     0.528519
# mean_test_score                                                       0.510366
# std_test_score                                                        0.015938
# rank_test_score                                                             15
# split0_train_score                                                    0.632101
# split1_train_score                                                     0.61509
# split2_train_score                                                    0.633413
# split3_train_score                                                    0.626161
# split4_train_score                                                     0.61139
# split5_train_score                                                    0.636875
# split6_train_score                                                    0.638979
# split7_train_score                                                    0.640704
# split8_train_score                                                    0.638732
# split9_train_score                                                    0.641984
# mean_train_score                                                      0.631543
# std_train_score                                                       0.010188
#
#                                                                             17  \
# mean_fit_time                                                         4.291425
# std_fit_time                                                          0.062705
# mean_score_time                                                       0.148413
# std_score_time                                                        0.006365
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        75
# param_clf__min_samples_leaf                                                 10
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 7...
# split0_test_score                                                     0.495904
# split1_test_score                                                     0.507808
# split2_test_score                                                     0.490984
# split3_test_score                                                     0.514375
# split4_test_score                                                     0.515716
# split5_test_score                                                     0.527406
# split6_test_score                                                     0.512995
# split7_test_score                                                     0.510958
# split8_test_score                                                     0.526853
# split9_test_score                                                     0.534022
# mean_test_score                                                       0.513702
# std_test_score                                                         0.01286
# rank_test_score                                                             13
# split0_train_score                                                     0.61063
# split1_train_score                                                    0.607382
# split2_train_score                                                    0.601282
# split3_train_score                                                    0.605484
# split4_train_score                                                    0.604667
# split5_train_score                                                    0.607908
# split6_train_score                                                    0.608097
# split7_train_score                                                    0.618616
# split8_train_score                                                    0.605615
# split9_train_score                                                    0.614933
# mean_train_score                                                      0.608461
# std_train_score                                                        0.00484
#
#                                                                             18  \
# mean_fit_time                                                         5.306684
# std_fit_time                                                          0.053614
# mean_score_time                                                        0.15716
# std_score_time                                                        0.008856
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        80
# param_clf__min_samples_leaf                                                  2
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 8...
# split0_test_score                                                     0.501092
# split1_test_score                                                     0.517763
# split2_test_score                                                     0.519856
# split3_test_score                                                     0.528029
# split4_test_score                                                       0.5276
# split5_test_score                                                     0.517209
# split6_test_score                                                     0.530772
# split7_test_score                                                     0.504796
# split8_test_score                                                     0.530171
# split9_test_score                                                      0.54124
# mean_test_score                                                       0.521853
# std_test_score                                                        0.011662
# rank_test_score                                                              9
# split0_train_score                                                    0.675058
# split1_train_score                                                    0.669736
# split2_train_score                                                    0.677624
# split3_train_score                                                    0.683467
# split4_train_score                                                     0.67311
# split5_train_score                                                    0.671498
# split6_train_score                                                    0.678843
# split7_train_score                                                    0.684547
# split8_train_score                                                    0.680555
# split9_train_score                                                    0.682546
# mean_train_score                                                      0.677698
# std_train_score                                                        0.00493
#
#                                                                             19  \
# mean_fit_time                                                         4.850567
# std_fit_time                                                          0.071129
# mean_score_time                                                       0.155526
# std_score_time                                                        0.004609
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        80
# param_clf__min_samples_leaf                                                  5
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 8...
# split0_test_score                                                      0.48959
# split1_test_score                                                     0.498403
# split2_test_score                                                     0.509674
# split3_test_score                                                     0.509744
# split4_test_score                                                     0.535287
# split5_test_score                                                     0.539312
# split6_test_score                                                     0.527545
# split7_test_score                                                     0.502415
# split8_test_score                                                     0.533492
# split9_test_score                                                     0.518336
# mean_test_score                                                        0.51638
# std_test_score                                                        0.016216
# rank_test_score                                                             11
# split0_train_score                                                    0.639893
# split1_train_score                                                    0.619587
# split2_train_score                                                    0.639293
# split3_train_score                                                    0.645102
# split4_train_score                                                    0.640441
# split5_train_score                                                    0.647854
# split6_train_score                                                     0.64546
# split7_train_score                                                    0.648825
# split8_train_score                                                    0.645462
# split9_train_score                                                    0.644212
# mean_train_score                                                      0.641613
# std_train_score                                                       0.007965
#
#                                                                             20  \
# mean_fit_time                                                         4.444381
# std_fit_time                                                          0.039637
# mean_score_time                                                       0.150241
# std_score_time                                                        0.005033
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                        80
# param_clf__min_samples_leaf                                                 10
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 8...
# split0_test_score                                                     0.496255
# split1_test_score                                                     0.514001
# split2_test_score                                                     0.496396
# split3_test_score                                                     0.520736
# split4_test_score                                                      0.50955
# split5_test_score                                                      0.53273
# split6_test_score                                                     0.517698
# split7_test_score                                                     0.505951
# split8_test_score                                                     0.533175
# split9_test_score                                                     0.526059
# mean_test_score                                                       0.515255
# std_test_score                                                        0.012714
# rank_test_score                                                             12
# split0_train_score                                                    0.614492
# split1_train_score                                                    0.614383
# split2_train_score                                                    0.609152
# split3_train_score                                                    0.613428
# split4_train_score                                                    0.607329
# split5_train_score                                                    0.616019
# split6_train_score                                                    0.615939
# split7_train_score                                                    0.620309
# split8_train_score                                                    0.612152
# split9_train_score                                                    0.619956
# mean_train_score                                                      0.614316
# std_train_score                                                       0.003928
#
#                                                                             21  \
# mean_fit_time                                                         5.835257
# std_fit_time                                                          0.080411
# mean_score_time                                                        0.15909
# std_score_time                                                        0.006208
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       100
# param_clf__min_samples_leaf                                                  2
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 1...
# split0_test_score                                                     0.514656
# split1_test_score                                                     0.537413
# split2_test_score                                                     0.507897
# split3_test_score                                                     0.512203
# split4_test_score                                                      0.52457
# split5_test_score                                                      0.51969
# split6_test_score                                                     0.515133
# split7_test_score                                                     0.512357
# split8_test_score                                                     0.544057
# split9_test_score                                                     0.530091
# mean_test_score                                                       0.521807
# std_test_score                                                        0.011358
# rank_test_score                                                             10
# split0_train_score                                                    0.700795
# split1_train_score                                                    0.702556
# split2_train_score                                                    0.690027
# split3_train_score                                                    0.699657
# split4_train_score                                                    0.696997
# split5_train_score                                                    0.696582
# split6_train_score                                                    0.695982
# split7_train_score                                                    0.709258
# split8_train_score                                                    0.706601
# split9_train_score                                                    0.707948
# mean_train_score                                                       0.70064
# std_train_score                                                       0.005761
#
#                                                                             22  \
# mean_fit_time                                                         5.243169
# std_fit_time                                                          0.042371
# mean_score_time                                                       0.153565
# std_score_time                                                         0.01026
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       100
# param_clf__min_samples_leaf                                                  5
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 1...
# split0_test_score                                                     0.510823
# split1_test_score                                                      0.51932
# split2_test_score                                                     0.516847
# split3_test_score                                                      0.51344
# split4_test_score                                                     0.528359
# split5_test_score                                                     0.535101
# split6_test_score                                                     0.534514
# split7_test_score                                                     0.511319
# split8_test_score                                                     0.541973
# split9_test_score                                                     0.514198
# mean_test_score                                                        0.52259
# std_test_score                                                        0.010821
# rank_test_score                                                              8
# split0_train_score                                                    0.665636
# split1_train_score                                                    0.655489
# split2_train_score                                                    0.663305
# split3_train_score                                                    0.662553
# split4_train_score                                                    0.652278
# split5_train_score                                                    0.665635
# split6_train_score                                                    0.662089
# split7_train_score                                                    0.671044
# split8_train_score                                                    0.665932
# split9_train_score                                                    0.667939
# mean_train_score                                                       0.66319
# std_train_score                                                       0.005327
#
#                                                                             23  \
# mean_fit_time                                                         4.722827
# std_fit_time                                                          0.076154
# mean_score_time                                                       0.150747
# std_score_time                                                        0.009463
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       100
# param_clf__min_samples_leaf                                                 10
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 1...
# split0_test_score                                                      0.52545
# split1_test_score                                                     0.527156
# split2_test_score                                                        0.512
# split3_test_score                                                     0.529231
# split4_test_score                                                     0.535001
# split5_test_score                                                     0.534737
# split6_test_score                                                     0.542005
# split7_test_score                                                     0.520266
# split8_test_score                                                     0.538665
# split9_test_score                                                       0.5187
# mean_test_score                                                       0.528321
# std_test_score                                                        0.009024
# rank_test_score                                                              7
# split0_train_score                                                     0.63208
# split1_train_score                                                    0.638253
# split2_train_score                                                    0.628794
# split3_train_score                                                    0.631203
# split4_train_score                                                    0.634564
# split5_train_score                                                    0.630549
# split6_train_score                                                    0.637561
# split7_train_score                                                    0.639255
# split8_train_score                                                    0.631773
# split9_train_score                                                    0.635615
# mean_train_score                                                      0.633965
# std_train_score                                                       0.003417
#
#                                                                             24  \
# mean_fit_time                                                         7.584095
# std_fit_time                                                          0.107736
# mean_score_time                                                       0.155677
# std_score_time                                                        0.005161
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       200
# param_clf__min_samples_leaf                                                  2
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 2...
# split0_test_score                                                      0.54163
# split1_test_score                                                     0.558934
# split2_test_score                                                     0.544977
# split3_test_score                                                     0.535028
# split4_test_score                                                     0.546729
# split5_test_score                                                     0.554018
# split6_test_score                                                     0.554496
# split7_test_score                                                     0.536303
# split8_test_score                                                     0.571833
# split9_test_score                                                     0.549883
# mean_test_score                                                       0.549383
# std_test_score                                                        0.010521
# rank_test_score                                                              6
# split0_train_score                                                    0.794252
# split1_train_score                                                    0.783636
# split2_train_score                                                    0.786063
# split3_train_score                                                    0.784776
# split4_train_score                                                    0.779999
# split5_train_score                                                    0.785493
# split6_train_score                                                    0.793269
# split7_train_score                                                    0.789214
# split8_train_score                                                    0.784179
# split9_train_score                                                    0.791551
# mean_train_score                                                      0.787243
# std_train_score                                                       0.004397
#
#                                                                             25  \
# mean_fit_time                                                         6.539289
# std_fit_time                                                          0.086963
# mean_score_time                                                       0.151726
# std_score_time                                                         0.00491
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       200
# param_clf__min_samples_leaf                                                  5
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 2...
# split0_test_score                                                     0.546448
# split1_test_score                                                     0.558917
# split2_test_score                                                     0.544676
# split3_test_score                                                     0.539902
# split4_test_score                                                      0.57159
# split5_test_score                                                     0.573542
# split6_test_score                                                     0.565726
# split7_test_score                                                     0.537665
# split8_test_score                                                     0.570544
# split9_test_score                                                     0.537879
# mean_test_score                                                       0.554689
# std_test_score                                                        0.014112
# rank_test_score                                                              5
# split0_train_score                                                     0.73673
# split1_train_score                                                    0.726386
# split2_train_score                                                    0.732298
# split3_train_score                                                    0.726571
# split4_train_score                                                    0.724936
# split5_train_score                                                    0.730304
# split6_train_score                                                    0.734195
# split7_train_score                                                    0.732493
# split8_train_score                                                    0.727678
# split9_train_score                                                    0.731912
# mean_train_score                                                       0.73035
# std_train_score                                                       0.003644
#
#                                                                             26  \
# mean_fit_time                                                         5.664591
# std_fit_time                                                          0.116379
# mean_score_time                                                       0.147005
# std_score_time                                                        0.006138
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       200
# param_clf__min_samples_leaf                                                 10
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 2...
# split0_test_score                                                     0.563452
# split1_test_score                                                     0.568902
# split2_test_score                                                     0.552795
# split3_test_score                                                     0.571347
# split4_test_score                                                     0.573356
# split5_test_score                                                     0.584513
# split6_test_score                                                     0.574006
# split7_test_score                                                     0.551783
# split8_test_score                                                     0.579734
# split9_test_score                                                     0.551149
# mean_test_score                                                       0.567104
# std_test_score                                                        0.011304
# rank_test_score                                                              4
# split0_train_score                                                    0.700615
# split1_train_score                                                    0.695687
# split2_train_score                                                    0.694909
# split3_train_score                                                    0.692074
# split4_train_score                                                    0.687732
# split5_train_score                                                    0.695853
# split6_train_score                                                    0.698342
# split7_train_score                                                    0.698007
# split8_train_score                                                    0.698232
# split9_train_score                                                    0.698707
# mean_train_score                                                      0.696016
# std_train_score                                                        0.00358
#
#                                                                             27  \
# mean_fit_time                                                         9.664611
# std_fit_time                                                          0.202745
# mean_score_time                                                        0.15334
# std_score_time                                                        0.007042
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       500
# param_clf__min_samples_leaf                                                  2
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                     0.566172
# split1_test_score                                                     0.576701
# split2_test_score                                                     0.578019
# split3_test_score                                                     0.573699
# split4_test_score                                                     0.565811
# split5_test_score                                                     0.577166
# split6_test_score                                                     0.574186
# split7_test_score                                                     0.556068
# split8_test_score                                                     0.592713
# split9_test_score                                                     0.561278
# mean_test_score                                                       0.572181
# std_test_score                                                         0.00981
# rank_test_score                                                              3
# split0_train_score                                                    0.864665
# split1_train_score                                                    0.861845
# split2_train_score                                                    0.860236
# split3_train_score                                                    0.860086
# split4_train_score                                                    0.856645
# split5_train_score                                                    0.864223
# split6_train_score                                                    0.863261
# split7_train_score                                                    0.859326
# split8_train_score                                                    0.861251
# split9_train_score                                                    0.861315
# mean_train_score                                                      0.861285
# std_train_score                                                       0.002284
#
#                                                                             28  \
# mean_fit_time                                                         8.318921
# std_fit_time                                                          0.120209
# mean_score_time                                                       0.151666
# std_score_time                                                        0.008262
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       500
# param_clf__min_samples_leaf                                                  5
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                     0.588546
# split1_test_score                                                     0.589818
# split2_test_score                                                     0.581913
# split3_test_score                                                     0.579588
# split4_test_score                                                     0.595634
# split5_test_score                                                     0.610603
# split6_test_score                                                     0.596033
# split7_test_score                                                     0.569162
# split8_test_score                                                     0.613285
# split9_test_score                                                     0.568915
# mean_test_score                                                        0.58935
# std_test_score                                                        0.014441
# rank_test_score                                                              2
# split0_train_score                                                    0.795547
# split1_train_score                                                     0.79302
# split2_train_score                                                    0.795506
# split3_train_score                                                     0.79436
# split4_train_score                                                    0.794374
# split5_train_score                                                    0.794644
# split6_train_score                                                    0.796484
# split7_train_score                                                    0.795622
# split8_train_score                                                    0.793908
# split9_train_score                                                    0.795133
# mean_train_score                                                       0.79486
# std_train_score                                                       0.000949
#
#                                                                             29
# mean_fit_time                                                         6.877122
# std_fit_time                                                          0.210921
# mean_score_time                                                       0.140494
# std_score_time                                                        0.018436
# param_clf__criterion                                                      gini
# param_clf__max_depth                                                       500
# param_clf__min_samples_leaf                                                 10
# param_clf__splitter                                                       best
# param_tfidf__min_df                                                         20
# param_tfidf__ngram_range                                                (1, 3)
# param_tfidf__stop_words                                                english
# params                       {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                     0.596875
# split1_test_score                                                     0.591136
# split2_test_score                                                     0.593952
# split3_test_score                                                     0.610205
# split4_test_score                                                     0.595549
# split5_test_score                                                     0.612255
# split6_test_score                                                     0.603439
# split7_test_score                                                     0.575307
# split8_test_score                                                     0.605311
# split9_test_score                                                     0.583355
# mean_test_score                                                       0.596738
# std_test_score                                                        0.011043
# rank_test_score                                                              1
# split0_train_score                                                     0.74187
# split1_train_score                                                    0.745709
# split2_train_score                                                    0.742946
# split3_train_score                                                    0.745895
# split4_train_score                                                    0.743298
# split5_train_score                                                    0.745951
# split6_train_score                                                     0.74287
# split7_train_score                                                     0.74693
# split8_train_score                                                    0.740431
# split9_train_score                                                    0.746427
# mean_train_score                                                      0.744233
# std_train_score                                                       0.002107

# %%
# Higher Max_depth improved training performance but overfit the training data too much.  
# Going to a max_depth of 10 seemed to create parity between test and training, though 
# it's overall poor performance

# %%
Mads Features + tfidf

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
num_cols = ['d_chall_score','aoa_mean','aoa_min','aoa_max','conc_rating_mean','conc_rating_min', 'conc_rating_max','num_lemmas']

# %% [markdown]
# # TFIDF + Mads Features

# %%
from sklearn.pipeline import FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import KBinsDiscretizer




vectorizer = Pipeline([
              ('tfidf', TfidfVectorizer())])

mads_pipe = Pipeline([
              ('impute_mean',SimpleImputer(strategy='mean')),
              ('scaler',MinMaxScaler()),
              ('bin',KBinsDiscretizer(n_bins=4))
              ])

preprocessor = ColumnTransformer(transformers=[
    ('mads',mads_pipe,num_cols),
    ('text', vectorizer, 'lemmatized_text')
    ])


              
pipeline = Pipeline([('preprocessor', preprocessor),
                     ('clf', DecisionTreeClassifier()) # classifier
                     ])

# %%
tfidf_prefix = 'preprocessor__text__tfidf__'
clf_prefix = 'clf__'

parameters = {
    tfidf_prefix + 'min_df': [20],
    tfidf_prefix + 'stop_words': ['english'],
    tfidf_prefix + 'ngram_range' : [(1, 3)],
    'clf__criterion': ['gini'],
    'clf__splitter': ['best'],
    'clf__min_samples_leaf': [1,5,10],
    'clf__max_depth': [4,5,6]
}

grid_dtc_all_f1= (GridSearchCV(pipeline,
                                  param_grid=parameters,
                                  scoring='f1',
                                  n_jobs=-1,
                                  cv=StratifiedKFold(n_splits=10),
                                  return_train_score=True
                                  )).fit(X_train_samp,y_train_samp)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_discretization.py:233: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 5 are removed. Consider decreasing the number of bins.
#   "decreasing the number of bins." % jj

# %%
all_features_results = pd.DataFrame(grid_dtc_all_f1.cv_results_)

# %%
all_features_results.T
# Out:
#                                                                                               0  \
# mean_fit_time                                                                          2.371839
# std_fit_time                                                                           0.053608
# mean_score_time                                                                        0.161711
# std_score_time                                                                         0.007934
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          4
# param_clf__min_samples_leaf                                                                   1
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 4...
# split0_test_score                                                                       0.68111
# split1_test_score                                                                      0.645193
# split2_test_score                                                                      0.633226
# split3_test_score                                                                      0.676749
# split4_test_score                                                                      0.634859
# split5_test_score                                                                      0.655384
# split6_test_score                                                                      0.648004
# split7_test_score                                                                      0.639532
# split8_test_score                                                                      0.676133
# split9_test_score                                                                      0.678727
# mean_test_score                                                                        0.656892
# std_test_score                                                                          0.01842
# rank_test_score                                                                               7
# split0_train_score                                                                     0.675488
# split1_train_score                                                                     0.644885
# split2_train_score                                                                     0.646747
# split3_train_score                                                                     0.674854
# split4_train_score                                                                     0.645978
# split5_train_score                                                                     0.648999
# split6_train_score                                                                     0.646361
# split7_train_score                                                                     0.647166
# split8_train_score                                                                     0.671811
# split9_train_score                                                                      0.67412
# mean_train_score                                                                       0.657641
# std_train_score                                                                        0.013477
#
#                                                                                               1  \
# mean_fit_time                                                                          2.350779
# std_fit_time                                                                           0.044062
# mean_score_time                                                                        0.161918
# std_score_time                                                                         0.005262
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          4
# param_clf__min_samples_leaf                                                                   5
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 4...
# split0_test_score                                                                       0.68111
# split1_test_score                                                                      0.645193
# split2_test_score                                                                      0.633226
# split3_test_score                                                                      0.676451
# split4_test_score                                                                      0.634526
# split5_test_score                                                                      0.655384
# split6_test_score                                                                      0.648004
# split7_test_score                                                                      0.639532
# split8_test_score                                                                      0.676133
# split9_test_score                                                                      0.678727
# mean_test_score                                                                        0.656829
# std_test_score                                                                         0.018428
# rank_test_score                                                                               9
# split0_train_score                                                                     0.675437
# split1_train_score                                                                     0.644774
# split2_train_score                                                                     0.646637
# split3_train_score                                                                     0.674787
# split4_train_score                                                                     0.645904
# split5_train_score                                                                     0.648891
# split6_train_score                                                                     0.646326
# split7_train_score                                                                     0.647056
# split8_train_score                                                                     0.671711
# split9_train_score                                                                      0.67402
# mean_train_score                                                                       0.657554
# std_train_score                                                                        0.013483
#
#                                                                                               2  \
# mean_fit_time                                                                          2.359638
# std_fit_time                                                                           0.026273
# mean_score_time                                                                        0.168473
# std_score_time                                                                         0.011711
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          4
# param_clf__min_samples_leaf                                                                  10
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 4...
# split0_test_score                                                                       0.68111
# split1_test_score                                                                      0.645193
# split2_test_score                                                                      0.633226
# split3_test_score                                                                      0.676749
# split4_test_score                                                                      0.634859
# split5_test_score                                                                      0.655384
# split6_test_score                                                                      0.648004
# split7_test_score                                                                      0.639532
# split8_test_score                                                                      0.676133
# split9_test_score                                                                      0.678727
# mean_test_score                                                                        0.656892
# std_test_score                                                                          0.01842
# rank_test_score                                                                               7
# split0_train_score                                                                     0.675437
# split1_train_score                                                                     0.644832
# split2_train_score                                                                     0.646694
# split3_train_score                                                                     0.674803
# split4_train_score                                                                     0.645925
# split5_train_score                                                                     0.648891
# split6_train_score                                                                     0.646326
# split7_train_score                                                                     0.647113
# split8_train_score                                                                      0.67176
# split9_train_score                                                                     0.674069
# mean_train_score                                                                       0.657585
# std_train_score                                                                         0.01348
#
#                                                                                               3  \
# mean_fit_time                                                                          2.423544
# std_fit_time                                                                           0.047639
# mean_score_time                                                                        0.168616
# std_score_time                                                                         0.004058
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          5
# param_clf__min_samples_leaf                                                                   1
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                                      0.682882
# split1_test_score                                                                      0.679228
# split2_test_score                                                                      0.666667
# split3_test_score                                                                      0.673616
# split4_test_score                                                                      0.662896
# split5_test_score                                                                      0.683839
# split6_test_score                                                                      0.682417
# split7_test_score                                                                      0.670437
# split8_test_score                                                                       0.67239
# split9_test_score                                                                      0.674637
# mean_test_score                                                                        0.674901
# std_test_score                                                                         0.006773
# rank_test_score                                                                               1
# split0_train_score                                                                     0.679035
# split1_train_score                                                                     0.677887
# split2_train_score                                                                     0.679369
# split3_train_score                                                                     0.670807
# split4_train_score                                                                     0.680051
# split5_train_score                                                                     0.676809
# split6_train_score                                                                     0.678104
# split7_train_score                                                                     0.678558
# split8_train_score                                                                      0.67115
# split9_train_score                                                                      0.67013
# mean_train_score                                                                        0.67619
# std_train_score                                                                        0.003698
#
#                                                                                               4  \
# mean_fit_time                                                                          2.402359
# std_fit_time                                                                           0.044157
# mean_score_time                                                                        0.171687
# std_score_time                                                                         0.005594
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          5
# param_clf__min_samples_leaf                                                                   5
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                                      0.683182
# split1_test_score                                                                      0.679228
# split2_test_score                                                                      0.666667
# split3_test_score                                                                      0.673309
# split4_test_score                                                                      0.662291
# split5_test_score                                                                      0.683839
# split6_test_score                                                                      0.682417
# split7_test_score                                                                      0.670588
# split8_test_score                                                                      0.672082
# split9_test_score                                                                      0.674947
# mean_test_score                                                                        0.674855
# std_test_score                                                                         0.006925
# rank_test_score                                                                               2
# split0_train_score                                                                     0.678916
# split1_train_score                                                                     0.677703
# split2_train_score                                                                     0.679168
# split3_train_score                                                                     0.670668
# split4_train_score                                                                     0.679849
# split5_train_score                                                                     0.676658
# split6_train_score                                                                     0.678002
# split7_train_score                                                                      0.67834
# split8_train_score                                                                      0.67096
# split9_train_score                                                                     0.669974
# mean_train_score                                                                       0.676024
# std_train_score                                                                        0.003692
#
#                                                                                               5  \
# mean_fit_time                                                                          2.426115
# std_fit_time                                                                           0.045131
# mean_score_time                                                                        0.172808
# std_score_time                                                                          0.00634
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          5
# param_clf__min_samples_leaf                                                                  10
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 5...
# split0_test_score                                                                      0.682583
# split1_test_score                                                                      0.679228
# split2_test_score                                                                      0.666055
# split3_test_score                                                                      0.673616
# split4_test_score                                                                      0.662896
# split5_test_score                                                                      0.683839
# split6_test_score                                                                      0.682417
# split7_test_score                                                                      0.670287
# split8_test_score                                                                      0.672082
# split9_test_score                                                                      0.675258
# mean_test_score                                                                        0.674826
# std_test_score                                                                         0.006837
# rank_test_score                                                                               3
# split0_train_score                                                                     0.678704
# split1_train_score                                                                     0.677518
# split2_train_score                                                                     0.679101
# split3_train_score                                                                     0.670685
# split4_train_score                                                                     0.679714
# split5_train_score                                                                     0.676658
# split6_train_score                                                                     0.678002
# split7_train_score                                                                     0.678323
# split8_train_score                                                                     0.670822
# split9_train_score                                                                     0.670043
# mean_train_score                                                                       0.675957
# std_train_score                                                                        0.003652
#
#                                                                                               6  \
# mean_fit_time                                                                          2.459617
# std_fit_time                                                                           0.039699
# mean_score_time                                                                        0.170681
# std_score_time                                                                         0.009973
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          6
# param_clf__min_samples_leaf                                                                   1
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 6...
# split0_test_score                                                                      0.681308
# split1_test_score                                                                      0.671813
# split2_test_score                                                                      0.665409
# split3_test_score                                                                      0.676226
# split4_test_score                                                                      0.658747
# split5_test_score                                                                      0.680224
# split6_test_score                                                                       0.67521
# split7_test_score                                                                      0.666512
# split8_test_score                                                                      0.675475
# split9_test_score                                                                      0.676353
# mean_test_score                                                                        0.672728
# std_test_score                                                                         0.006763
# rank_test_score                                                                               5
# split0_train_score                                                                     0.675345
# split1_train_score                                                                       0.6747
# split2_train_score                                                                     0.676531
# split3_train_score                                                                     0.674699
# split4_train_score                                                                     0.675134
# split5_train_score                                                                     0.673824
# split6_train_score                                                                     0.674209
# split7_train_score                                                                     0.675372
# split8_train_score                                                                     0.675654
# split9_train_score                                                                     0.673872
# mean_train_score                                                                       0.674934
# std_train_score                                                                        0.000804
#
#                                                                                               7  \
# mean_fit_time                                                                          2.491002
# std_fit_time                                                                           0.130549
# mean_score_time                                                                         0.16372
# std_score_time                                                                         0.004087
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          6
# param_clf__min_samples_leaf                                                                   5
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 6...
# split0_test_score                                                                      0.681308
# split1_test_score                                                                      0.671813
# split2_test_score                                                                      0.665409
# split3_test_score                                                                       0.67592
# split4_test_score                                                                      0.658122
# split5_test_score                                                                      0.680851
# split6_test_score                                                                      0.674587
# split7_test_score                                                                      0.666358
# split8_test_score                                                                      0.675782
# split9_test_score                                                                      0.677268
# mean_test_score                                                                        0.672742
# std_test_score                                                                         0.007011
# rank_test_score                                                                               4
# split0_train_score                                                                     0.674915
# split1_train_score                                                                     0.674304
# split2_train_score                                                                     0.675997
# split3_train_score                                                                     0.674285
# split4_train_score                                                                     0.674737
# split5_train_score                                                                     0.673375
# split6_train_score                                                                     0.673878
# split7_train_score                                                                      0.67494
# split8_train_score                                                                     0.675274
# split9_train_score                                                                     0.673746
# mean_train_score                                                                       0.674545
# std_train_score                                                                        0.000745
#
#                                                                                               8
# mean_fit_time                                                                          2.369948
# std_fit_time                                                                           0.184085
# mean_score_time                                                                        0.158913
# std_score_time                                                                         0.020166
# param_clf__criterion                                                                       gini
# param_clf__max_depth                                                                          6
# param_clf__min_samples_leaf                                                                  10
# param_clf__splitter                                                                        best
# param_preprocessor__text__tfidf__min_df                                                      20
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_preprocessor__text__tfidf__stop_words                                             english
# params                                        {'clf__criterion': 'gini', 'clf__max_depth': 6...
# split0_test_score                                                                      0.680682
# split1_test_score                                                                      0.672587
# split2_test_score                                                                      0.664151
# split3_test_score                                                                      0.676069
# split4_test_score                                                                      0.658747
# split5_test_score                                                                         0.681
# split6_test_score                                                                      0.675204
# split7_test_score                                                                      0.666358
# split8_test_score                                                                      0.674553
# split9_test_score                                                                      0.677728
# mean_test_score                                                                        0.672708
# std_test_score                                                                         0.006978
# rank_test_score                                                                               6
# split0_train_score                                                                     0.674998
# split1_train_score                                                                     0.674353
# split2_train_score                                                                     0.675619
# split3_train_score                                                                     0.674196
# split4_train_score                                                                      0.67458
# split5_train_score                                                                     0.673305
# split6_train_score                                                                     0.673687
# split7_train_score                                                                     0.674767
# split8_train_score                                                                     0.674862
# split9_train_score                                                                     0.673864
# mean_train_score                                                                       0.674423
# std_train_score                                                                        0.000652

# %%
grid_dtc_all_f1.best_params_
# Out:
# {'clf__criterion': 'gini',
#  'clf__max_depth': 5,
#  'clf__min_samples_leaf': 1,
#  'clf__splitter': 'best',
#  'preprocessor__text__tfidf__min_df': 20,
#  'preprocessor__text__tfidf__ngram_range': (1, 3),
#  'preprocessor__text__tfidf__stop_words': 'english'}

# %%
tfidf_best_params = {k[len(tfidf_prefix):]:v 
                     for (k, v) in grid_dtc_all_f1.best_params_.items() 
                     if tfidf_prefix in k}

clf_best_params = {k[len(clf_prefix):]:v 
                   for (k, v) in grid_dtc_all_f1.best_params_.items() 
                   if clf_prefix in k}

num_pipe = Pipeline([
    ('impute', SimpleImputer(strategy='mean')),
    ('binner', KBinsDiscretizer(n_bins=4)),
])

text_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(**tfidf_best_params)),
])

preprocessor = ColumnTransformer([
    ('num', num_pipe, num_cols),
    ('text', text_pipe, 'lemmatized_text'),
])

clf = Pipeline([
    ('preprocessor', preprocessor),
    ('clf', DecisionTreeClassifier(**clf_best_params)),
])

# %%
X_train, X_val, y_train, y_val = train_test_split(train[num_cols + ['lemmatized_text']], 
                                                  train['label'],
                                                  stratify=train['label'], 
                                                  random_state=99)

# %%
clf = clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_discretization.py:233: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 5 are removed. Consider decreasing the number of bins.
#   "decreasing the number of bins." % jj

# %%
model_name = "decision tree"
for k,v in grid_dtc_all_f1.best_params_.items():
  model_name +=f' {v}'

# %%
compute_metrics(clf,model_name,X_train,y_train, X_val, y_val)

# %%
pd.DataFrame(metrics_df).T
# Out:
#                                                                  0
# model_name           decision tree gini 5 1 best 20 (1, 3) english
# model_instance   (ColumnTransformer(transformers=[('num',\n    ...
# train_accuracy                                            0.644951
# train_precision                                            0.61973
# train_recall                                              0.750268
# train_f1                                                   0.67878
# train_aucprc                                               0.71947
# train_aucroc                                               0.67934
# test_accuracy                                             0.640046
# test_precision                                            0.616063
# test_f1                                                   0.673761
# test_recall                                               0.743383
# test_aucprc                                               0.717242
# test_aucroc                                               0.675823

# %%
# Extract the feature names from the vectorizer and combine with the numeric (mads) features

text_features_trf = (clf['preprocessor']
                 .transformers_[1][1]
                 ['tfidf']
                 .get_feature_names_out())


num_features_trf = (clf['preprocessor']
                    .transformers_[0][1]
                    ['binner']
                    .get_feature_names_out(num_cols))


all_features_trf = list(num_features_trf) + list(text_features_trf)

# %%
# Generate the image and save off in our shared drive

dot_data = tree.export_graphviz(clf['clf'],
                                feature_names=all_features_trf,
                                filled=True)
graph = graphviz.Source(dot_data)
graph.render(filename='decision_tree.gv',
             directory=filepath,
             format='png'
             )
# Out:
# 'drive/Shareddrives/Milestone 2/decision_tree.gv.png'

# %%
import seaborn as sns

# %%
sns.barplot(
    

    
)
# Out:
# (24209,)

# %%
clf['clf']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-194-b2a78e05160e> in <module>
# ----> 1 feat_importance = clf['clf'].feature_importance_
#       2 features_sorted = np.argsort(feat_importance)[::-1]
#       3 features_sorted
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'feature_importance_'
