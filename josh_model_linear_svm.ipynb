# %% [markdown]
# <a href="https://colab.research.google.com/github/Tstrebe2/predicting-text-difficulty/blob/josh-updates/josh_model_linear_svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

import pandas as pd
import numpy as np

from sklearn.svm import LinearSVC
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, KBinsDiscretizer
from sklearn.ensemble import BaggingClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# parameters
sample_size = 5000

# Which numeric features to include
features = {
    'd_chall_score': True, 
    'aoa_mean': False, 
    'aoa_min': False, 
    'aoa_max': True,
    'conc_rating_mean': False, 
    'conc_rating_min': False, 
    'conc_rating_max': True, 
    'num_lemmas': True
}

# %%
# load datasets
train = pd.read_csv('/content/drive/Shareddrives/Milestone 2/Training_set.csv', delimiter='\t', index_col='ix')
train['lemmatized_text'] = train['lemmatized_text'].fillna('')

test = pd.read_csv('/content/drive/Shareddrives/Milestone 2/Testing_set.csv', delimiter='\t', index_col='ix')
test['lemmatized_text'] = test['lemmatized_text'].fillna('')

# collect feature list for df slicing
num_features = [k for k,v in features.items() if v]
txt_features = 'lemmatized_text'

# %%
# build pipeline object

# pipeline for numeric features
num_pipe = Pipeline([
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler()),
    ('binner', KBinsDiscretizer(n_bins=4)),
])

# pipeline for text features
text_pipe = Pipeline([
    ('tfidf', TfidfVectorizer()),
])

# integration of numeric and text features
preprocessor = ColumnTransformer([
    ('num', num_pipe, num_features),
    ('text', text_pipe, txt_features),
])

# final pipeline
clf = Pipeline([
    ('preprocessor', preprocessor),
    ('svc', LinearSVC(dual=False))
])

# %%
n = len(train) if sample_size == -1 else sample_size # to sample or not to sample

# sample the dataframe with balanced classes
sample_df = train.groupby('label').apply(lambda grp: grp.sample(int(n/2), random_state=99))

# %%
# prep grid search
tfidf_prefix = 'preprocessor__text__tfidf__'
svc_prefix = 'svc__'

# specify grid parameters
param_grid = {tfidf_prefix + 'min_df':[0],
              tfidf_prefix + 'max_df':[0.1, 0.5, 1.0],
              tfidf_prefix + 'ngram_range':[(1,3)],
              svc_prefix + 'C': [0.01, 0.1, 0.5, 1], 
              # svc_prefix + 'C': [0.5], 
              # svc_prefix + 'penalty': ['l1','l2'],
              svc_prefix + 'penalty': ['l1'],
              # svc_prefix + 'kernel':['rbf'],
              svc_prefix + 'random_state':[99]}

# create and fit grid object
grid = (GridSearchCV(clf, 
                    param_grid=param_grid,
                    scoring='accuracy', 
                    cv=StratifiedKFold(n_splits=10),
                    refit=False,
                    verbose=3,
                    return_train_score=True,
                    n_jobs=-1)
        .fit(sample_df, sample_df['label']))
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits

# %%
print(grid.best_params_)
cvr = pd.DataFrame(grid.cv_results_)
cvr[cvr['rank_test_score'] <= 5].sort_values(by='rank_test_score') .T
# Out:
# {'preprocessor__text__tfidf__max_df': 0.5, 'preprocessor__text__tfidf__min_df': 0, 'preprocessor__text__tfidf__ngram_range': (1, 3), 'svc__C': 0.5, 'svc__penalty': 'l1', 'svc__random_state': 99}
#                                                                                              6   \
# mean_fit_time                                                                          1.185879
# std_fit_time                                                                           0.059873
# mean_score_time                                                                        0.050166
# std_score_time                                                                         0.003818
# param_preprocessor__text__tfidf__max_df                                                     0.5
# param_preprocessor__text__tfidf__min_df                                                       0
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_svc__C                                                                                0.5
# param_svc__penalty                                                                           l1
# param_svc__random_state                                                                      99
# params                                        {'preprocessor__text__tfidf__max_df': 0.5, 'pr...
# split0_test_score                                                                         0.646
# split1_test_score                                                                         0.662
# split2_test_score                                                                         0.646
# split3_test_score                                                                         0.684
# split4_test_score                                                                         0.666
# split5_test_score                                                                          0.61
# split6_test_score                                                                         0.682
# split7_test_score                                                                          0.69
# split8_test_score                                                                         0.632
# split9_test_score                                                                         0.646
# mean_test_score                                                                          0.6564
# std_test_score                                                                         0.023963
# rank_test_score                                                                               1
# split0_train_score                                                                     0.681778
# split1_train_score                                                                     0.685556
# split2_train_score                                                                     0.678222
# split3_train_score                                                                     0.675333
# split4_train_score                                                                     0.674889
# split5_train_score                                                                     0.683556
# split6_train_score                                                                     0.678667
# split7_train_score                                                                     0.676222
# split8_train_score                                                                     0.678889
# split9_train_score                                                                     0.681111
# mean_train_score                                                                       0.679422
# std_train_score                                                                         0.00336
#
#                                                                                              2   \
# mean_fit_time                                                                          1.228118
# std_fit_time                                                                           0.095539
# mean_score_time                                                                        0.050062
# std_score_time                                                                         0.002842
# param_preprocessor__text__tfidf__max_df                                                     0.1
# param_preprocessor__text__tfidf__min_df                                                       0
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_svc__C                                                                                0.5
# param_svc__penalty                                                                           l1
# param_svc__random_state                                                                      99
# params                                        {'preprocessor__text__tfidf__max_df': 0.1, 'pr...
# split0_test_score                                                                          0.66
# split1_test_score                                                                         0.658
# split2_test_score                                                                         0.646
# split3_test_score                                                                         0.694
# split4_test_score                                                                         0.664
# split5_test_score                                                                         0.626
# split6_test_score                                                                         0.664
# split7_test_score                                                                          0.68
# split8_test_score                                                                         0.626
# split9_test_score                                                                         0.644
# mean_test_score                                                                          0.6562
# std_test_score                                                                         0.020522
# rank_test_score                                                                               2
# split0_train_score                                                                     0.679111
# split1_train_score                                                                     0.683778
# split2_train_score                                                                     0.675556
# split3_train_score                                                                     0.675556
# split4_train_score                                                                     0.674889
# split5_train_score                                                                     0.680667
# split6_train_score                                                                     0.675778
# split7_train_score                                                                     0.673111
# split8_train_score                                                                     0.676667
# split9_train_score                                                                     0.674889
# mean_train_score                                                                          0.677
# std_train_score                                                                         0.00306
#
#                                                                                              10  \
# mean_fit_time                                                                          1.186136
# std_fit_time                                                                               0.05
# mean_score_time                                                                        0.052659
# std_score_time                                                                         0.007368
# param_preprocessor__text__tfidf__max_df                                                     1.0
# param_preprocessor__text__tfidf__min_df                                                       0
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_svc__C                                                                                0.5
# param_svc__penalty                                                                           l1
# param_svc__random_state                                                                      99
# params                                        {'preprocessor__text__tfidf__max_df': 1.0, 'pr...
# split0_test_score                                                                         0.648
# split1_test_score                                                                         0.662
# split2_test_score                                                                         0.644
# split3_test_score                                                                         0.684
# split4_test_score                                                                         0.666
# split5_test_score                                                                          0.61
# split6_test_score                                                                          0.68
# split7_test_score                                                                         0.688
# split8_test_score                                                                         0.632
# split9_test_score                                                                         0.646
# mean_test_score                                                                           0.656
# std_test_score                                                                         0.023495
# rank_test_score                                                                               3
# split0_train_score                                                                     0.682889
# split1_train_score                                                                     0.684667
# split2_train_score                                                                     0.678667
# split3_train_score                                                                     0.675556
# split4_train_score                                                                     0.674222
# split5_train_score                                                                     0.683111
# split6_train_score                                                                     0.678444
# split7_train_score                                                                     0.676889
# split8_train_score                                                                     0.678222
# split9_train_score                                                                     0.681111
# mean_train_score                                                                       0.679378
# std_train_score                                                                        0.003276
#
#                                                                                              3   \
# mean_fit_time                                                                          1.275732
# std_fit_time                                                                           0.067766
# mean_score_time                                                                        0.053406
# std_score_time                                                                         0.008322
# param_preprocessor__text__tfidf__max_df                                                     0.1
# param_preprocessor__text__tfidf__min_df                                                       0
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_svc__C                                                                                  1
# param_svc__penalty                                                                           l1
# param_svc__random_state                                                                      99
# params                                        {'preprocessor__text__tfidf__max_df': 0.1, 'pr...
# split0_test_score                                                                         0.642
# split1_test_score                                                                          0.65
# split2_test_score                                                                         0.632
# split3_test_score                                                                         0.688
# split4_test_score                                                                         0.678
# split5_test_score                                                                         0.628
# split6_test_score                                                                         0.676
# split7_test_score                                                                          0.67
# split8_test_score                                                                         0.636
# split9_test_score                                                                         0.654
# mean_test_score                                                                          0.6554
# std_test_score                                                                          0.02024
# rank_test_score                                                                               4
# split0_train_score                                                                     0.751333
# split1_train_score                                                                     0.748667
# split2_train_score                                                                     0.748222
# split3_train_score                                                                        0.746
# split4_train_score                                                                     0.741556
# split5_train_score                                                                        0.756
# split6_train_score                                                                     0.740222
# split7_train_score                                                                     0.743556
# split8_train_score                                                                        0.746
# split9_train_score                                                                     0.746889
# mean_train_score                                                                       0.746844
# std_train_score                                                                        0.004396
#
#                                                                                              11
# mean_fit_time                                                                          1.268074
# std_fit_time                                                                             0.0904
# mean_score_time                                                                        0.049095
# std_score_time                                                                          0.00589
# param_preprocessor__text__tfidf__max_df                                                     1.0
# param_preprocessor__text__tfidf__min_df                                                       0
# param_preprocessor__text__tfidf__ngram_range                                             (1, 3)
# param_svc__C                                                                                  1
# param_svc__penalty                                                                           l1
# param_svc__random_state                                                                      99
# params                                        {'preprocessor__text__tfidf__max_df': 1.0, 'pr...
# split0_test_score                                                                          0.64
# split1_test_score                                                                         0.672
# split2_test_score                                                                          0.64
# split3_test_score                                                                         0.682
# split4_test_score                                                                         0.672
# split5_test_score                                                                         0.616
# split6_test_score                                                                         0.688
# split7_test_score                                                                          0.67
# split8_test_score                                                                          0.63
# split9_test_score                                                                         0.638
# mean_test_score                                                                          0.6548
# std_test_score                                                                         0.023464
# rank_test_score                                                                               5
# split0_train_score                                                                     0.755333
# split1_train_score                                                                     0.747778
# split2_train_score                                                                     0.746222
# split3_train_score                                                                     0.746889
# split4_train_score                                                                     0.745778
# split5_train_score                                                                        0.756
# split6_train_score                                                                     0.742889
# split7_train_score                                                                     0.745111
# split8_train_score                                                                     0.748444
# split9_train_score                                                                        0.746
# mean_train_score                                                                       0.748044
# std_train_score                                                                        0.004072

# %%
# setup final model
num_pipe = Pipeline([
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler()),
    ('binner', KBinsDiscretizer(n_bins=4)),
])

text_pipe = Pipeline([ 
    ('tfidf', TfidfVectorizer(min_df=0, max_df=0.5, ngram_range=(1,3))),
])

preprocessor = ColumnTransformer([
    ('num', num_pipe, num_features),
    ('text', text_pipe, txt_features),
])

# used CalibratedClassifier to allow use of predict_proba
svc = Pipeline([
    ('preprocessor', preprocessor),
    ('svc', CalibratedClassifierCV(LinearSVC(penalty='l1', C=0.5, dual=False, max_iter=10000, random_state=99))),
])

# %%
# split with balanced classes
X_train, X_val, y_train, y_val = train_test_split(train[num_features + [txt_features]], 
                                                  train['label'],
                                                  stratify=train['label'], 
                                                  random_state=99)

svc = svc.fit(X_train, y_train)

# predictions
train_y_proba = svc.predict_proba(X_train)[:, 1]
train_y_hat = svc.predict(X_train)

val_y_proba = svc.predict_proba(X_val)[:, 1]
val_y_hat = svc.predict(X_val)

# calculate and display metrics
train_roc_auc = metrics.roc_auc_score(y_train, train_y_proba)
train_accuracy = metrics.accuracy_score(y_train, train_y_hat)
train_f1 = metrics.f1_score(y_train, train_y_hat)
train_precision = metrics.precision_score(y_train, train_y_hat)
train_recall = metrics.recall_score(y_train, train_y_hat)

val_roc_auc = metrics.roc_auc_score(y_val, val_y_proba)
val_accuracy = metrics.accuracy_score(y_val, val_y_hat)
val_f1 = metrics.f1_score(y_val, val_y_hat)
val_precision = metrics.precision_score(y_val, val_y_hat)
val_recall = metrics.recall_score(y_val, val_y_hat)

print()
print('Train ROC AUC:', train_roc_auc)
print('Train Accuracy Score:', train_accuracy)
print('Train F1 Score:', train_f1)
print('Train Precision Score:', train_precision)
print('Train Recall Score:', train_recall)
print()
print('Validation ROC AUC:', val_roc_auc)
print('Validation Accuracy Score:', val_accuracy)
print('Validation F1 Score:', val_f1)
print('Validation Precision Score:', val_precision)
print('Validation Recall Score:', val_recall)

# %%
# from joblib import dump

# dump(svc, 'svc-model_v5.joblib')
# Out:
# ['svc-model_v5.joblib']

# %%
from joblib import load
svc_old = load('svc-model_v4.joblib')

# %%
svc_old.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor', ColumnTransformer(transformers=[('num',
#                                     Pipeline(steps=[('impute', SimpleImputer()),
#                                                     ('scale', StandardScaler()),
#                                                     ('binner',
#                                                      KBinsDiscretizer(n_bins=4))]),
#                                     ['d_chall_score', 'aoa_max', 'conc_rating_max',
#                                      'num_lemmas']),
#                                    ('text',
#                                     Pipeline(steps=[('tfidf',
#                                                      TfidfVectorizer(max_df=1000000,
#                                                                      min_df=0,
#                                                                      ngram_range=(1,
#                                                                                   3)))]),
#                                     'lemmatized_text')])),
#   ('svc', CalibratedClassifierCV(base_estimator=LinearSVC(C=0.5, dual=False,
#                                                    max_iter=10000, penalty='l1')))],
#  'verbose': False,
#  'preprocessor': ColumnTransformer(transformers=[('num',
#                                   Pipeline(steps=[('impute', SimpleImputer()),
#                                                   ('scale', StandardScaler()),
#                                                   ('binner',
#                                                    KBinsDiscretizer(n_bins=4))]),
#                                   ['d_chall_score', 'aoa_max', 'conc_rating_max',
#                                    'num_lemmas']),
#                                  ('text',
#                                   Pipeline(steps=[('tfidf',
#                                                    TfidfVectorizer(max_df=1000000,
#                                                                    min_df=0,
#                                                                    ngram_range=(1,
#                                                                                 3)))]),
#                                   'lemmatized_text')]),
#  'svc': CalibratedClassifierCV(base_estimator=LinearSVC(C=0.5, dual=False,
#                                                  max_iter=10000, penalty='l1')),
#  'preprocessor__n_jobs': None,
#  'preprocessor__remainder': 'drop',
#  'preprocessor__sparse_threshold': 0.3,
#  'preprocessor__transformer_weights': None,
#  'preprocessor__transformers': [('num',
#    Pipeline(steps=[('impute', SimpleImputer()), ('scale', StandardScaler()),
#                    ('binner', KBinsDiscretizer(n_bins=4))]),
#    ['d_chall_score', 'aoa_max', 'conc_rating_max', 'num_lemmas']),
#   ('text', Pipeline(steps=[('tfidf',
#                     TfidfVectorizer(max_df=1000000, min_df=0,
#                                     ngram_range=(1, 3)))]), 'lemmatized_text')],
#  'preprocessor__verbose': False,
#  'preprocessor__verbose_feature_names_out': True,
#  'preprocessor__num': Pipeline(steps=[('impute', SimpleImputer()), ('scale', StandardScaler()),
#                  ('binner', KBinsDiscretizer(n_bins=4))]),
#  'preprocessor__text': Pipeline(steps=[('tfidf',
#                   TfidfVectorizer(max_df=1000000, min_df=0,
#                                   ngram_range=(1, 3)))]),
#  'preprocessor__num__memory': None,
#  'preprocessor__num__steps': [('impute', SimpleImputer()),
#   ('scale', StandardScaler()),
#   ('binner', KBinsDiscretizer(n_bins=4))],
#  'preprocessor__num__verbose': False,
#  'preprocessor__num__impute': SimpleImputer(),
#  'preprocessor__num__scale': StandardScaler(),
#  'preprocessor__num__binner': KBinsDiscretizer(n_bins=4),
#  'preprocessor__num__impute__add_indicator': False,
#  'preprocessor__num__impute__copy': True,
#  'preprocessor__num__impute__fill_value': None,
#  'preprocessor__num__impute__missing_values': nan,
#  'preprocessor__num__impute__strategy': 'mean',
#  'preprocessor__num__impute__verbose': 0,
#  'preprocessor__num__scale__copy': True,
#  'preprocessor__num__scale__with_mean': True,
#  'preprocessor__num__scale__with_std': True,
#  'preprocessor__num__binner__dtype': None,
#  'preprocessor__num__binner__encode': 'onehot',
#  'preprocessor__num__binner__n_bins': 4,
#  'preprocessor__num__binner__strategy': 'quantile',
#  'preprocessor__text__memory': None,
#  'preprocessor__text__steps': [('tfidf',
#    TfidfVectorizer(max_df=1000000, min_df=0, ngram_range=(1, 3)))],
#  'preprocessor__text__verbose': False,
#  'preprocessor__text__tfidf': TfidfVectorizer(max_df=1000000, min_df=0, ngram_range=(1, 3)),
#  'preprocessor__text__tfidf__analyzer': 'word',
#  'preprocessor__text__tfidf__binary': False,
#  'preprocessor__text__tfidf__decode_error': 'strict',
#  'preprocessor__text__tfidf__dtype': numpy.float64,
#  'preprocessor__text__tfidf__encoding': 'utf-8',
#  'preprocessor__text__tfidf__input': 'content',
#  'preprocessor__text__tfidf__lowercase': True,
#  'preprocessor__text__tfidf__max_df': 1000000,
#  'preprocessor__text__tfidf__max_features': None,
#  'preprocessor__text__tfidf__min_df': 0,
#  'preprocessor__text__tfidf__ngram_range': (1, 3),
#  'preprocessor__text__tfidf__norm': 'l2',
#  'preprocessor__text__tfidf__preprocessor': None,
#  'preprocessor__text__tfidf__smooth_idf': True,
#  'preprocessor__text__tfidf__stop_words': None,
#  'preprocessor__text__tfidf__strip_accents': None,
#  'preprocessor__text__tfidf__sublinear_tf': False,
#  'preprocessor__text__tfidf__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'preprocessor__text__tfidf__tokenizer': None,
#  'preprocessor__text__tfidf__use_idf': True,
#  'preprocessor__text__tfidf__vocabulary': None,
#  'svc__base_estimator__C': 0.5,
#  'svc__base_estimator__class_weight': None,
#  'svc__base_estimator__dual': False,
#  'svc__base_estimator__fit_intercept': True,
#  'svc__base_estimator__intercept_scaling': 1,
#  'svc__base_estimator__loss': 'squared_hinge',
#  'svc__base_estimator__max_iter': 10000,
#  'svc__base_estimator__multi_class': 'ovr',
#  'svc__base_estimator__penalty': 'l1',
#  'svc__base_estimator__random_state': None,
#  'svc__base_estimator__tol': 0.0001,
#  'svc__base_estimator__verbose': 0,
#  'svc__base_estimator': LinearSVC(C=0.5, dual=False, max_iter=10000, penalty='l1'),
#  'svc__cv': None,
#  'svc__ensemble': True,
#  'svc__method': 'sigmoid',
#  'svc__n_jobs': None}

# %%
# predictions
train_y_proba = svc_old.predict_proba(X_train)[:, 1]
train_y_hat = svc_old.predict(X_train)

val_y_proba = svc_old.predict_proba(X_val)[:, 1]
val_y_hat = svc_old.predict(X_val)

# metrics
train_roc_auc = metrics.roc_auc_score(y_train, train_y_proba)
train_accuracy = metrics.accuracy_score(y_train, train_y_hat)
train_f1 = metrics.f1_score(y_train, train_y_hat)
train_precision = metrics.precision_score(y_train, train_y_hat)
train_recall = metrics.recall_score(y_train, train_y_hat)

val_roc_auc = metrics.roc_auc_score(y_val, val_y_proba)
val_accuracy = metrics.accuracy_score(y_val, val_y_hat)
val_f1 = metrics.f1_score(y_val, val_y_hat)
val_precision = metrics.precision_score(y_val, val_y_hat)
val_recall = metrics.recall_score(y_val, val_y_hat)

print()
print('Train ROC AUC:', train_roc_auc)
print('Train Accuracy Score:', train_accuracy)
print('Train F1 Score:', train_f1)
print('Train Precision Score:', train_precision)
print('Train Recall Score:', train_recall)
print()
print('Validation ROC AUC:', val_roc_auc)
print('Validation Accuracy Score:', val_accuracy)
print('Validation F1 Score:', val_f1)
print('Validation Precision Score:', val_precision)
print('Validation Recall Score:', val_recall)
# Out:
# Train ROC AUC: 0.8352929383264309
# Train Accuracy Score: 0.7526189130488876
# Train F1 Score: 0.7562493651688739
# Train Precision Score: 0.7453089402830514
# Train Recall Score: 0.7675157650772435
#
# Validation ROC AUC: 0.7932213084485933
# Validation Accuracy Score: 0.716762820854617
# Validation F1 Score: 0.7234600807963016
# Validation Precision Score: 0.7067559045507252
# Validation Recall Score: 0.7409729775844051
